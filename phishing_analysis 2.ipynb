# %% [markdown]
# # Phishing URL Dataset Analysis 📊

# %% [markdown]
# ### Preview of Dataset

# %%
import pandas as pd
import math
import re
from urllib.parse import urlparse
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import RobustScaler
from sklearn.feature_selection import RFE
from sklearn.metrics import precision_score, recall_score, f1_score

import numpy as np

# %%
dataset_count = 60000

# %%
df_phish = pd.read_csv("SimpleExtension/datasets/verified_online.csv")
df_benign = pd.read_csv('SimpleExtension/datasets/top-1m.csv', header=None, names=['rank', 'domain'])

# %%
df_phish.head()
# Out:
#    phish_id                          url  \
# 0   9060784  https://txtag.org-lgco.vip/
# 1   9060781  https://txtag.org-kzgt.vip/
# 2   9060779  https://txtag.org-hujf.vip/
# 3   9060778  https://txtag.org-hkrc.vip/
# 4   9060777  https://txtag.org-fqlt.vip/
#
#                                     phish_detail_url  \
# 0  http://www.phishtank.com/phish_detail.php?phis...
# 1  http://www.phishtank.com/phish_detail.php?phis...
# 2  http://www.phishtank.com/phish_detail.php?phis...
# 3  http://www.phishtank.com/phish_detail.php?phis...
# 4  http://www.phishtank.com/phish_detail.php?phis...
#
#              submission_time verified          verification_time online target
# 0  2025-04-14T09:01:17+00:00      yes  2025-04-14T12:12:08+00:00    yes  Other
# 1  2025-04-14T09:01:04+00:00      yes  2025-04-14T12:12:08+00:00    yes  Other
# 2  2025-04-14T09:00:45+00:00      yes  2025-04-14T12:12:08+00:00    yes  Other
# 3  2025-04-14T09:00:23+00:00      yes  2025-04-14T12:12:08+00:00    yes  Other
# 4  2025-04-14T09:00:08+00:00      yes  2025-04-14T12:12:08+00:00    yes  Other

# %%
phishing_urls = df_phish['url'].dropna().sample(n=dataset_count, random_state=42).tolist()
phishing_urls
# Out:
# ['https://l.wl.co/l?u=https://qr-codes.io/dBL24Y',
#  'https://atttjsjsupport.webflow.io/',
#  'https://jdvcqs.e-scurefiles.net/',
#  'https://l.ead.me/bfPT6O',
#  'https://allegrolokalnie.id8791244.shop/',
#  'https://l.ead.me/bfJb0t',
#  'https://zfechtp.xin/',
#  'https://ezpass.com-etcoe.xin/',
#  'https://appeal-check.firebaseapp.com/',
#  'http://rastrobel.com.br/esfera/gomeuspontos864',
#  'https://t.co/TW6S3CIuBi',
#  'https://1291823.weebly.com/',
#  'https://gsuaplysutelta.weebly.com/',
#  'https://bit.ly/3Uc4ZzN',
#  'https://cgd-invalidarpt.com/',
#  'https://onlineaccess-3riversfcu.firebaseapp.com/',
#  'https://e-zpassny.com-ert.vip/',
#  'https://bozpprofi.cz/?url=https://fx18042023fxdocs93w81-1317797611.cos.ap-chengdu.myqcloud.com/f.html',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSVTEq-NBDdpAArybQflmSD9j84R9Br9zCjUbhXZpvf3CnBxVWapBqrVbYuIXlF5fZHK5lSn4r5fwrq/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://evrimail.online-servicessc.xin/',
#  'https://new.express.adobe.com/webpage/5suMXLTGhzYtF',
#  'https://bit.ly/4hrJRzu',
#  'https://bafybeigjfxi5gdy67tcnm3ikcaye4uj6rpzjcbkpu4xvuch7sekpfuv7m4.ipfs.dweb.link/',
#  'http://allegrolokalnie.pi-kategorie-dom-i-ogrod-99821.rest',
#  'https://tinyurl.com/yc2f4nm2',
#  'https://univ-frr.web.app/',
#  'https://secure--blockfie-sso--ccdn.webflow.io/',
#  'http://optikgeneral.com/Webmail/39/Webmail/webmail.php',
#  'https://avisosbanrurals.webcindario.com/Lucks.html?i=1',
#  'https://l.ead.me/bfWgJU',
#  'https://q-r.to/bfJiQL',
#  'https://svsdsdsdse.weebly.com/',
#  'https://dhddhdj.weebly.com/',
#  'https://myvisionsfedscuonline7g0indexmainvfcuphpvf.weebly.com/',
#  'https://bit.ly/ihe_check_1?utm_source=Inside+Higher+Ed&utm_campaign=5e05e5cf75-S2_DailyNews_COPY_01&utm_medium=email&utm_term=0_-284161f8c0-238016430&mc_cid=5e05e5cf75&mc_eid=UNIQID)',
#  'https://www.dropbox.com/scl/fi/ws6lcl1d2mhmy9eg36dvr/BT-ACCESS-PAGE.paper?rlkey=bjhw2bp0hrv4rd160nqmqjh29&dl=0',
#  'https://matheusmanuel.github.io/nubank-redesign-/',
#  'http://hemnanipublicschool.com/Webmail/88/Webmail/webmail.php',
#  'https://sunpass.com-etc-omoo.top/',
#  'https://q-r.to/bfKtbF',
#  'https://d32fgx.webwave.dev/',
#  'https://allegrolokalnie.pl-78992344.icu/aukcja/lodowka-przenosna-kompresorowa-12-24-230v-vigo-cool-36l-sprezarkowa--663536',
#  'https://hedgehogbabiesofincofr.firebaseapp.com/',
#  'https://uttvyvy.daftpage.com/',
#  'https://ezpass.com-helpr.vip/',
#  'https://l.ead.me/bfI21t',
#  'https://ssur.cc/iBper-lT',
#  'https://ledguer-logon.webflow.io/',
#  'https://reurl.cc/ZZ5yql',
#  'https://home-101904.weeblysite.com/',
#  'https://home-102434.weeblysite.com/',
#  'https://pub-2916f79c02924f4090d165d00e7d0ff0.r2.dev/index.html',
#  'https://bancopan.beedoo.io/login',
#  'https://forms.gle/CB8yqiUyXrEbgafo8',
#  'https://shorturl.at/wRTU8',
#  'https://e-zpass.com-jnz.xin/',
#  'https://s.id/www-roblox-com-gamesBlox-FruitsprivateServer',
#  'https://com-etcqha.vip/',
#  'https://bit.ly/4dYY2cR',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSLSb-CH5LWdMUW5FDNt3Gn57ix7KBj8GNHwOGQnEFG7EW_8VGDjV6yms5iT9aJ2PzGJJln_Nh3oq3k/pub?start=false&loop=false&delayms=3000',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQu1UDwZ4j-bx_ey7I3OtgVYZ9CqSbWWh6ufuRyTUm5oCpmCydFuTdViL2KrL8c9TE1LW_dXoHTdh8w/pub?start=false&amp;loop=false&amp;delayms=3000&amp;slide=id.p',
#  'https://l.ead.me/bfWrEk',
#  'https://lhv-panka-022.in.net/LHV/',
#  'https://secure.paymxnsxekr.top/',
#  'https://bit.ly/4egifdO',
#  'https://receptionorange4.wixsite.com/my-site?user-agent=Rlypnde/7.1',
#  'https://sites.google.com/view/webweitergmxdutechlogin/home',
#  'https://txtag.org-ytkz.vip/',
#  'https://hbciverify.weebly.com/',
#  'https://0nlinenterpriseandtrust.weebly.com/',
#  'https://home-101824.weeblysite.com/',
#  'http://allegrolokalnie.pl-oferta5466835.icu',
#  'https://www.dropbox.com/scl/fi/k78jxqjqr4whux7o9ed1e/BRITISH-TELECOMMUNICATION.paper?dl=0&rlkey=gej2imcft1xzsag8ujp1hjmua',
#  'https://masxx.weebly.com/',
#  'https://sites.google.com/view/wqdqwdqe/home&gt;',
#  'https://nnfems.com/Webmail/55/Webmail/webmail.php',
#  'https://thetollroads-tollevasiontnd.xin/',
#  'https://currently-attm.weebly.com/',
#  'http://allegrolokalnie.pl-92032932.rest',
#  'https://jemi.so/gjensidegkundeservice-1-2-2-1',
#  'https://smartsauth.firebaseapp.com/',
#  'https://currently9534.weebly.com/',
#  'https://l.wl.co/l?u=https://qrco.de/bfEGif',
#  'https://a11sprachboxlogde.weebly.com/',
#  'https://e-zpasspw-ny.xin/',
#  'https://jbalkamkaa.blogspot.com/',
#  'https://start-trezor-wallet-cloudd.webflow.io/',
#  'https://l.ead.me/bfftW1',
#  'https://cz-109657.weeblysite.com/',
#  'http://oneandonlykeaisland.us-east-1.linodeobjects.com/index.html',
#  'https://t.co/W5tQTFxJZa',
#  'https://com-eusxhkawcharys.top/',
#  'https://l.ead.me/bfII1J',
#  'https://q-r.to/dgtespana',
#  'https://tinyurl.com/5a67uecw',
#  'https://l.wl.co/l?u=https://ungu.in/etrhserfnjhsej45uh',
#  'https://bnvftfhfgfcfg.weebly.com/',
#  'https://www.dropbox.com/scl/fi/kzu9ysjw0qx40nxpzv9u1/BT-BROADBAND.papert?dl=0&rlkey=2e3577vz5ywlruhfvyw3ajprv&st=bs1rqtrb',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSqv9pHU4C8ozuI37rIq7zjjehWFa-Yj-B8oho7hViG8pGV7RE-zaxKYa1JJxXXWvKh_XjhWi82KpJO/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://pub-79a185974e3943ec84e87ef929f8ca94.r2.dev/gene3.html',
#  'https://tuiyrfsz.vip/',
#  'https://cl12.mlr.hu/dQ/XJysyQFq01nwfVMi/AqxA/XD4E/oV_M',
#  'https://qrco.de/brEew6',
#  'https://pub-0748065cf4614065b7cd1a15c09f1804.r2.dev/plesk1.html',
#  'https://attbettermentteam.weebly.com/',
#  'https://apps--itrustcapital-com-auth.webflow.io/',
#  'https://ezpass.com-ylylyls.xin/',
#  'https://e-zpass.com-etctye.vip/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRJG_S40t2EIAT5NsPtCJepAB8U40C4wv7cgqM5DMMwJXBARQJfAWwFm98e9fd0pRpkk-SLtfpBHj27/pub?start=false&loop=false&delayms=3000',
#  'https://zerion-inc.webflow.io/',
#  'https://docs.google.com/presentation/d/1QlnmWd33YPsuoEHdTWHnAgh8jy2asVHa8ZpybjRh5XI/pub?start=false&loop=false&delayms=3000&slide=id.p',
#  'https://l.ead.me/bfVSKC',
#  'http://online.web2020marketing.com/dsfdsds/dsfdsds/expect.php?r=...',
#  'https://sunpass.com-suncds.vip/',
#  'https://hbnxj.dailyprojecttools.com/index.php?em=redacted@abuse.ionos.com',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTgFxGt1kCvYVOuUO91T0-u92KnRi8MtBVKCIEAv8pYA5dOSQeeGTuVF0gp8uEGq_LqL-eK0J69RQjA/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://davescetlem.firebaseapp.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vT7bCZi6M0XTZvhiTC_Xb1pImWikpv1VanlCI54Ohz4V1D1D5P0mWGSBL9fXMMb7gWCXlsksluWPm2b/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://mndot-etzwep.xin/',
#  'http://hemnanipublicschool.com/Webmail/69/Webmail/webmail.php',
#  'https://bantrabenlinea0.webcindario.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRoo9WfrFOv9wqFW5O07N3bxfbZILtc0o7BPUFZU8qTpL7B7qS8fwrtxmSs0GCi6CD0iEVb5pCavvZ9/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://vist-phantom-wllety.webflow.io/',
#  'https://bt-102116.weeblysite.com/',
#  'https://ezpass.com-eztf.vip/',
#  'https://keystonesupport.pages.dev/3rd-party-wallets/eth-and-web3-wallets-keystone/bind-metamask-with-keystone/how-to-use-metamask-keystone-with-defi',
#  'https://docs.google.com/presentation/d/1OOXkLX-lnIAb6dmTmpE9wP-HR1o37uA9VcA9rkJTkdY/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://evri.com-evri.live/',
#  'https://etcyf.win/',
#  'https://www.shorturl.at/Aevqe',
#  'https://docs.google.com/presentation/d/1a_-pbNu3VmVJ7B9yV7kqaWnyzGY_nVTc_HmZi0SDK5s/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://pub-ef462d7acb154774b46edc1fe7338c29.r2.dev/index.html',
#  'https://ncbwf.cn/OYvPuYOk',
#  'https://wrtrery3.weebly.com/',
#  'https://byycrctyaa.firebaseapp.com/#abuse@example.com',
#  'https://usps.com-tracking-xxxin.cc/',
#  'https://elleslespetitdechance.firebaseapp.com/',
#  'https://l.ead.me/bfbZRP',
#  'https://qrco.de/bfJXmj',
#  'https://post.takeai.top/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vT8YLBDnu7kqoSI2Sb-2er73ca7e7CmSVcv48v-FozNTSHouoGAdms4n_3Gg7G43zZJwKEfnxvkV4Wj/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://bit.ly/4dysham',
#  'https://ezpass.com-ezmi.vip/',
#  'https://ggeeminiloginss.webflow.io/',
#  'https://trzzorriostrrtio.webflow.io/',
#  'https://inserm-desk.weebly.com/',
#  'https://currently84753.weebly.com/',
#  'https://vodsystem.weebly.com/',
#  'https://harrhrgb.vip/',
#  'https://sites.google.com/view/c4t4fwectv',
#  'https://secure-blockfie-azure---auth.webflow.io/',
#  'https://q-r.to/bfEwql',
#  'https://biglobemail11.wixsite.com/my-site',
#  'https://mndot-etzdgl.xin/',
#  'https://bit.ly/3OZznds',
#  'https://t.co/19wH7GnO2b',
#  'https://sjfkeno.web.app/',
#  'https://account.booking.com/sign-in?op_token=_IO0pzI',
#  'https://goodresultacademy.weebly.com/',
#  'http://185.163.125.142/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQeFp3ntXPzgLHhl-5PMPHoUbxj2BulAPeiohaV44o3qTgxvxsMeUUUa73oecE-XUV008sUPztbqDF4/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQw7HnyuwkToHHQJ1uQmTJqJGReq-kjh1ZFlMKG60kSmdEBTGrXdmPmaNoLXm-hzqUcZccghbHUSsZg/pub?start=true&amp;loop=true&amp;delayms=1000',
#  'https://saslklkmkiujjdheys.weebly.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTbPQzPNrmxDretCdjJlJRfreLpLtCixenvakIh9-NSakwQJRvf8JW1D2Xo9q5KugKIFOCX2dqiQYS9/pub?start=false&loop=false&delayms=3000',
#  'https://q-r.to/bfMB9K',
#  'https://l.ead.me/bfO05s',
#  'https://sites.google.com/view/ploskifodel',
#  'https://q-r.to/bfJftF',
#  'https://froneddaadafafafdad.weebly.com/',
#  'https://sunpass.com-nmp.vip/',
#  'https://store108574004.company.site/',
#  'https://q-r.to/bfQ0Ul',
#  'https://ghdjtyreafrtryts-hjrewqafdn.teemill.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQaOEPJTLOrH-daNUkDSA7taGlkLBiEb056ZKN8XQ-Og3H9duGKyNRTBLhwKSyv1JG_od4rFCYcuKib/pub?start=true&amp;loop=true&amp;delayms=60000',
#  'https://l.ead.me/bfKRFM',
#  'https://lobstrawalet.webflow.io/',
#  'https://snetmailsecure.weebly.com/',
#  'https://qrco.de/bfROTM',
#  'https://btconnect-voicemail.weebly.com/',
#  'https://thelotrustcapita.webflow.io/',
#  'https://l.ead.me/bfQcIJ',
#  'https://sbcglobalmailindependent.weebly.com/',
#  'https://uspq.khjjfkui.top/?breadcrumb=2426&detail=ufyp5a5&email=69282cfc993e95ad72791j&jlx=38ozwm',
#  'https://tinyurl.com/anzuf79v',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQ9dZMj38O8-U6CmREI-MXKtYiy4XgkGIvqzLW3CccvMn5K6p0ej5rAP3mJHDk4llem4cMsNpTt8ArV/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://creditas-zb.sentry.io/auth/login/creditas-zb/',
#  'https://mettmuskloginen.webflow.io/',
#  'https://evrimail.online-servicesio.xin/',
#  'https://pub-40ad58af455047d9a464b18a5f622876.r2.dev/abjkdnnndkjmdUSER02052024UNIQUE10200502292024202405022010291715603921606.html',
#  'https://bit.ly/2210strp7',
#  'https://telegram-desk.com/login/',
#  'https://txtag.org-qtb.vip/',
#  'https://docs.google.com/forms/d/e/1FAIpQLSc-mo_3oV-T64LK3bG0vaoqd9EDINJp2rlEsXiJxZFlVzCyFg/viewform?usp=send_form',
#  'https://t.co/HSSA6edLtc',
#  'https://docs.google.com/presentation/d/1ajepKtA5JZengL9hyln7ZwApAZXw0aBDAmYVsf4Frlo/pub?start=false&amp;loop=false&amp;delayms=3000&amp;slide=id.p',
#  'https://stepp19-ced6c.web.app/',
#  'https://pub-149d4d9c6d584b858c08016d778c9c30.r2.dev/index.html',
#  'https://myhnscomfcvu.weebly.com/',
#  'https://tahb-36ef2.web.app/',
#  'https://embertracker-flameweaver.blogspot.ch/',
#  'https://sosogn-21fdd.firebaseapp.com/',
#  'https://bit.ly/3W4abXu',
#  'https://confirm-support-iinfo.start.page/',
#  'https://apartmentdoor01.weebly.com/',
#  'https://bit.ly/3SlhFn0',
#  'https://jauniceverattisbannars.firebaseapp.com/',
#  'http://allegro.pl-oferta443532.rest',
#  'https://docs.google.com/presentation/d/e/2PACX-1vR8cLNSJnBttIb4KZNnxXnUiOeDWTXbw7ZuDXf_VLRAJzhwUGGy3EuKg9FRyUm0xvoEkL-yZfp40sDU/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://com-zblf.top/',
#  'https://webmail-chalmers-se-owa.weebly.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQcnY-xw7j9OnYp21khr1nBIwYA3n6NkOinSBQfEdxxiGoBP2zENH1VaDo4_m08W3Ff7Lgx3sn7jTdY/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://new.express.adobe.com/webpage/mtO0soBDWVpHU',
#  'https://qrco.de/bfdKjZ',
#  'https://sign-in-att-108414.weeblysite.com/',
#  'https://vid-refund.firebaseapp.com/',
#  'https://makerrdao.github.io/en/',
#  'https://tinyurl.com/ma2m3',
#  'https://leagirr--com-start.webflow.io/',
#  'https://ldyflaj50.ukit.me/',
#  'https://usps.com-cona.xin/us/',
#  'https://taubergruppe-my.sharepoint.com/:o:/g/personal/carl-christian_kahle_skbgmbh_de/EmRkpLurOeFJh5mO5sYovgwBSBlRXgMVjfp8Z0I1rI9i6Q?e=VYheh4',
#  'https://desmondcooper6.wixsite.com/atllt',
#  'https://identifiez-vous55.godaddysites.com/identifiez-vous',
#  'https://davescetlem.web.app/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSkkEheYGVghgFfoJ43ogjTi2j81uBEsaUmJDVQ5fON4uxAOtjVX8Vevx0qtNo7f-CWObBiXs94UD08/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://olx.bonidelnk.cfd/payment/79b538a18bd4/millennium',
#  'https://att-105803.weeblysite.com/',
#  'https://metacase1003125111.firebaseapp.com/',
#  'https://www.cakeresume.com/s--7KcCbSAO9gp-4IskKwkN0A--/ecwprdjebms',
#  'https://ylnk.cc/hcR9',
#  'https://deepp--bssniiees--674838.start.page/',
#  'https://ipfs.best-practice.se/ipfs/bafybeidnfm2ye6tblalqfoetcquomk5yr4hyl77ozeyookff3kwgown6ai',
#  'https://zpassmn.com-qnce.top/',
#  'https://bit.ly/3XRA8uS',
#  'https://currentlymailvailt2.weebly.com/',
#  'https://bit.ly/4eN7Mrc',
#  'https://bit.ly/3Wni7Ub',
#  'https://com-etcqna.vip/',
#  'https://owennos1.wixsite.com/my-site',
#  'https://nebimtis.firebaseapp.com/',
#  'http://allegrolokalnie.oferta864636.shop',
#  'https://docs.google.com/presentation/d/1HG24PRwtQiAtzLnFrslWf0kbK68fRzF7zQQZIh3dn-g/pub?start=false&amp;loop=false&amp;delayms=3000&amp;slide=id.p',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSVjWXCmFE9tWaoZbSJX4aUjjUM6Qx7NvJXL2kJcVJhVEGEw6i7nw6NNXpmKaOiDWomseFuGIDWpI-Z/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://allegro.pl-7113942.shop',
#  'https://t.co/N28TaQLvEs',
#  'https://thetollroads-tollevasioncfl.xin/',
#  'https://bit.ly/3y2rrDh',
#  'https://currentlyatt0login7.weebly.com/',
#  'https://provinciaringreso.online',
#  'https://secure-admin-gob-pe.weebly.com/',
#  'https://submit-dispute-form.github.io/review',
#  'https://scotyfcr.web.app/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vR80zdHvdh5gi2u2v_V8M-SgvQ9GG1Yfij48hMP9urTnfICzsSDI3Tt88WohJ-NAGt6C3OM3inmf1JE/pub?start=false',
#  'http://allegrolokainie.pl-propozycje-inne-72726.sbs',
#  'https://joshbystrom.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTKR83ODDQXOn2dGgUo4Pc25qDn8bkfn6-O6tcK03bUVtZRe-red8BJXD6O4pdbeSUaAEBNzhyBGsXe/pub?start=false&amp;loop=false&amp;delayms=3000&amp;slide=id.p',
#  'https://txtag.org-lmro.vip/',
#  'https://accountsettingnew-supportcenter-verifypages.pages.dev/',
#  'https://support-notify0.web.app/',
#  'https://sk-slovensko-dph.firebaseapp.com/',
#  'http://syr-whistler.com',
#  'https://com-ticketwsd.xin/',
#  'http://allegrolokalnie.ppl-oferta-firmowa734214.icu',
#  'http://q-r.to/serviceupdate-inc324',
#  'https://start-docs-trizor-start.webflow.io/',
#  'https://guipatrice49.wixsite.com/my-site-1',
#  'https://l.ead.me/bfYSuW',
#  'https://docs.google.com/presentation/d/e/2PACX-1vR0IGh7WDgc92mzvGXRhjXm81I8hoe_0-pcJS-oGdsWNLt4ewfTIzkoEg2xyBYro793lzdaAEdeWLyR/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://sites.google.com/view/update-currIP:',
#  'https://mtahelp.weebly.com/',
#  'https://strt-ttrezor-ios.webflow.io/',
#  'https://oifekme.xin/',
#  'https://anti-robot-4abac.firebaseapp.com/',
#  'https://pub-3b4356e259614550a3fb0f8bd5c092fa.r2.dev/construction-contrector-appliccations-waiv.html',
#  'https://sunpass.com-etc-hgsg.top/',
#  'https://manouvellelivraison.com/pac/',
#  'https://e-zpass.net-bived.top/',
#  'https://l.ead.me/bfatEN',
#  'https://ttrezxr-walltt.gitbook.io/us',
#  'https://magic.ly/atts?email=Rngugi%40sbcglobal.net',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQdiYrPaZyq1i7Jcewt6fYvnpG6ZWpdB_QNRp8DDMLq9tQi0XTfnCfDXf1EAGK9KuWQbt8-1rCA0tyK/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://secure.e-zpasspm.xin/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSm_NWyCVXvVCG23mHjsoQORrAnpmX_WdmB01gbnh-Xbh9qUMe1lyFsKO4K2a5YoC1e33b2aglcYDrL/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://amangroup.co/gy/linkedin_/',
#  'https://txtag.org-txtagstorefrontxiq.xin/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRyNaOVp2cFxHhkNHC37_MWX7tikkst2PtMQ7eJyHcyldK9XRb93N-yR9FzKBXvX3Bh1nqSI2x3aZjU/pub?start=false&loop=false&delayms=3000',
#  'https://jackywoor07943581.activehosted.com/f/1',
#  'https://nonurnse.sbs/updates',
#  'https://qrco.de/bfaIU4CDRnzOB1xbA?trackingid=VK5mYpBlg4I1xFA&amp;signature=newsletter',
#  'https://trezor--wallet-sso.webflow.io/',
#  'https://inc-106288.weeblysite.com/',
#  'https://metamaskconnect.web.app/',
#  'https://godaieducation.org/index.html',
#  'https://secure.etcslx.win/',
#  'https://reprogrammation-mondialcolis.com/pac/calcul.php',
#  'https://sites.google.com/view/atttyahoo/home',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQ2Qwjj9B4BVnh-8hsbkBiTQWirfYUA-CbWVOcU2bQxff4mkawWcldF1lsRZ4RPD3NcillFnST5BnYJ/pub?start=false&loop=false&delayms=3000',
#  'https://new.express.adobe.com/webpage/5Bd7eqJjK83Z9',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQwn2DWjhMI86qi9ucKfk40yE7ifQLWxv9WU6dfs3bkpb29AKf2rcTxOtL5Ok_7cyDVWxwMlS9RU35G/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://jenrrsgedine.web.app/',
#  'https://usps.com-sjzq.xin/',
#  'https://pub-5d2be2ec5f8c4467814e55e60cbc6176.r2.dev/index.html',
#  'https://usbmrezpasscom.vip/',
#  'http://proxy-sec-beyond-11-5-2024-ffarctdqaagmekea.eastus-01.azurewebsites.net/puppeteer-content-retry?url=https://www.sfr.fr',
#  'https://pub-f9199264effc4603af5309ffb3fd8c82.r2.dev/index.html',
#  'https://pub-8096fad52b1245db89c562ae1a44e8c3.r2.dev/index.html',
#  'https://wq60e.com/update',
#  'https://portalnutrimania.com.br/0000000000000000000000000000000000/',
#  'https://jun-july.weebly.com/',
#  'https://thesafepaldappsolution.web.app/',
#  'https://corroier.weebly.com/',
#  'http://banruvoice.webcindario.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQtv2TbIVd91IvKIArkG8gryPlLJIy_0W41KEK06MPvQUk0hDbLte05tzoT2-5Ty4yLQR4PQoEmdo2T/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://eneeeetsowww.blogspot.com/?m=0',
#  'https://qrco.de/rD31J0Zs1d/?NUpxE2VRH2fdlv1fKjL7OKBOzlc0oyHA',
#  'https://com-etcqhz.vip/',
#  'https://sppwlaasdnejdswwsmnd.weebly.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQioChlnpupoZA-9L-7-jTkKtay9gM_Fh7Gest5mpMFQwTjHutUOGFm7SGz6SHxNpaFPO_vKFzgPt-r/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSHQPBqBg35Alf2Mi8FsA6GaiDaoRUxcyZHdmAJ-thWDlY3lL6p_vsHeuF2cs9mti5mMk1uz1V3PLW-/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://att-mail-106093.weeblysite.com/',
#  'https://content--oouth-ledgres.webflow.io/',
#  'https://new.express.adobe.com/webpage/a5gymIq4sZBvF',
#  'https://syncomm01xzx.weebly.com/',
#  'https://mypeachpass.com-bkkx.xin/',
#  'https://reagan-107341.weeblysite.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTVvDsaM2ij0aQxBb9swSoVYi8_2DIKX4jWyIhY8eb8Nh5BQrbgZxgW8bBR03FJttHG3i6-IV2CLl8E/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://toddwithrow.com/wp-content/',
#  'https://chkgenra.web.app/',
#  'https://new.express.adobe.com/webpage/vTPDqbNXZYgQ1',
#  'https://docs.google.com/presentation/d/1CXxQHJNtdtjq96nKfUop6lBcn-FdIMY9NHSE38vuchA/pub?start=false&loop=false&delayms=3000&slide=id.p',
#  'https://at-t-mail-update.pory.app/',
#  'https://telstra-100582.weeblysite.com/',
#  'https://linkin.bio/ferryhooby/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vS5WuM1lMT9rOJG71vtJs1YPScQp26E4Si4zTu6RhnbiT4rOO2AxWS67QW7DNkuEK0fndxIhDTlyyhX/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://new.express.adobe.com/webpage/qtH8Liy42D9MQ',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSvNSrBSOjHXJ-SL-g1tYzCvGL0NXObo_oT7yAk8mS3YTm2nYDXGE2g9owUfKYaytt43XmZp2y8zfAa/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://ledger--support--start-ledgerlve.webflow.io/',
#  'https://click7.att.net.oauth-account.45-11-59-206.cprapid.com/tewrewiuhdsgbf=topireuyhdujigfda',
#  'https://cur.to/attt',
#  'https://new.express.adobe.com/webpage/e6cVP9NqXkJrv',
#  'https://mailzimbracom.weebly.com/',
#  'https://txtag.org-mdjpk.top/',
#  'https://new.express.adobe.com/webpage/zWKlNn0JRjuma',
#  'https://docs.google.com/presentation/d/112fmlH7g0rSYBcm4vBkBFXMq5z1FabDhz4VddehmcYc/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://us3.yunkedu.com/',
#  'https://ebnkng-ch3.mein-postfach-ch.com/aktualisieren/home.php',
#  'https://ln.run/ajys8',
#  'https://bit.ly/48Qb8Yg',
#  'https://mygoodtogo.com-upfw.vip/',
#  'https://secure.accountaz.xin/',
#  'https://gdewu.cn/monex',
#  'https://bt-update-108795.weeblysite.com/',
#  'https://e-zpass.com-etcph.xin/',
#  'https://uniswap.token.im/',
#  'https://tyedud.weebly.com/',
#  'http://xn--d1aqfkf.xn--p1ai/bitrix/.../GlobalSources/?email=jerwin@clmgcorp.com',
#  'https://1152db1.wcomhost.com/',
#  'https://ezpass.com-hbngd.xin/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vS3AkSRAhSZSB1BZk-gPdCjlpMsqXEYr6BtXtaXQcFWTxwh6HoXeYd2Jyt85QtG0eTt2HC_FKEjMyPk/pub?start=false&loop=false&delayms=3000&slide=id.p',
#  'https://agervusgnrale.web.app/',
#  'https://qrco.de/bfVx4e',
#  'https://com-eusxhkawdu.xin/',
#  'https://q-r.to/bfbWtF',
#  'https://dwload--ledgre-web.webflow.io/',
#  'https://pub-a92b0046bffd456c97472996f7080e8f.r2.dev/index.html',
#  'https://com-yij.xin/',
#  'https://acount-verifieds.start.page/',
#  'https://evri.psocysgxw.xin/',
#  'https://accracityrealtygh.com/wp-content/spk.php',
#  'https://bit.ly/3BIZUbZ',
#  'http://allegrolokalnie.pl-oferta-9847331.shop',
#  'https://lobestrewallet.webflow.io/',
#  'https://l.ead.me/bfJuIC',
#  'https://q-r.to/bfI1Ds',
#  'https://kraken-logiv.webflow.io',
#  'https://qrco.de/bfKlcL',
#  'https://q-r.to/bfJQTe',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRa0nO3bo38lJMBWXvkTFCsa0XwegaTVh9TjMkq0sBr8J-TX_XmeXA9eVtH8TSmIcDpGFjdGMKIvsYN/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://bit.ly/3xv3moI',
#  'https://www.dropbox.com/scl/fi/xs5b6d59p6mzlxtyf6qeh/CLICK-TO-CONTINUE-SIGN-IN.paper?dl=0&rlkey=u42md1bnw846o3enf479kqcne',
#  'https://telstrahomeiuytrd6548765.weebly.com/',
#  'https://messsageriezim.weebly.com/',
#  'https://mondiai-colisreiay.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQsxfVUOnUMxtKF7Degp4eGqNo5xyidJ7-ImIbwycorEMJ3UKBcEC-O4wj-BnwV8KULMv-GdsE5d0fw/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://pub-a36543f24029434ebd100d279177a0aa.r2.dev/zyamcqdzzxkzcawjbvdojzrrwheuegohpellssscdgubi.html',
#  'https://seivviice.weebly.com/',
#  'https://www.dailymorningcoffee.com/fthjx.php',
#  'https://bravauce-gold.web.app/',
#  'https://ezpass.com-edkx.top/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQRiCRnMBGEeU9geoC6pBujgKRO-qBW9vG-QnIZ0deREmZAGRaRRWCYohx59TP69AyRbNghbM_ahloM/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://com-lpjf.top/',
#  'https://freeplaystationplus1.weebly.com/',
#  'https://docs.google.com/presentation/d/1GTQ9_cgMP6ViFOFzknooCqcY3Y6N7eB74zoN6gJgBmU/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://welltai--live--ledgre.webflow.io/',
#  'https://servidordecorreo.weebly.com/',
#  'https://xfinityloadingtovoiveinf0.weebly.com/',
#  'https://crimson-mode-0c42.yellowprivate.workers.dev/1992502101/48001712/1459192180gB0xZ2VuLzk3NTQyMDExMi8xNzcwNjYxOTA2L2F4aGF1c2VuLzYyMDAwODU0My9pdnQuYmF1Zy5ldGh6LmNoL01UazFNRFl5TWpZNE5RPT0',
#  'https://share-na3.hsforms.com/16oOQMusURhqfCrRPkjqg5Q5nf2ci',
#  'https://bestesgrous.firebaseapp.com/',
#  'https://l.ead.me/LaPost',
#  'https://www.dropbox.com/scl/fi/74lcki5ejseaq4qpx53um/WELCOME-TO-YOUR-BT-MAIL.paper?dl=0&rlkey=wcklpq3vlqzwjiitd8o21q53o',
#  'https://bowkwpoedjjeodkkseksdnkdnfndnebebbdbdbndjdnd.ttrbru.eu.org/',
#  'https://sites.google.com/view/richieeverizonhjk/home',
#  'https://sites.google.com/view/update-currently1017/update',
#  'https://vk.com/away.php?utf=1&to=https%3A%2F%2Fxn--43-6kcuuwiekcalje.xn--p1ai%2Fplugins%2Fcontent%2Fcontact%2Findex.php',
#  'https://phantom-cdn-wallet-help.webflow.io',
#  'https://reurl.cc/XmlOpg',
#  'https://u43168371.ct.sendgrid.net/ls/click?upn=u001.rzgDthwf-2FCl2vuIydvWFBm9URZxoIKqKm3LHJBgMq8GB2tjp6hiF22hUY5808Qx8gzl7sUwBEl1sb6rGhcCfbzvC2kLpLyFjjev-2FgiZc4HvCAlB5Q0ec6kOzS4TypnlV5GUr1jg0fwFCXRjlLy2V2A-3D-3DGncz_z-2FYaNCHtLChffN0B-2Bs6HV1M6p3YbF5fsumuI5nX72FXyd8O0y7RbZLEF8ZzZBpVnWGxb9yf1TzpmWMHDjnXe6u31t5G-2Bbjo8h9piFEolqsCs3SR3TVyT7dMAYrdxnc-2BnM6l-2FziW58VD0o1tiX0Lud1JVU387K8UbSqnbeb9OZSxwdaoM8HeMlJUy4uqk-2B9CFWX1mjHLZpAb36nTxZIO61g-3D-3D',
#  'https://4484471d.orson.website/?utm_source=ActiveCampaign&utm_medium=email&utm_content=MISLP&utm_campaign=Nouvelle%20campagne%20%28Copie%29%20%28Copie%29',
#  'https://qrco.de/bfJZQz',
#  'https://ipfs.best-practice.se/ipfs/QmYjF8noea9s5giQWSkywwWKUKJGVHMpxTZzQxPpxRbj3J',
#  'https://whimsical.com/Y64FdYDd4yDmTdL1wH2VsU',
#  'https://cetnob52224.activehosted.com/f/1',
#  'https://uptodatebuzmaincentrevowsebcserver.weebly.com/',
#  'https://my1stcb.weebly.com/',
#  'https://pay.hotmart.com/U97310070J?bid=1736174797090',
#  'http://sharepoint-trinitybusinessgroup.net',
#  'https://4hpplh8y.forms.app/validation-gratuite-dpd-group',
#  'https://sunpass.com-passc.vip/',
#  'https://43.153.117.17/',
#  'http://zuza.stefek.szczecin.pl/Webmail/49/Webmail/webmail.php',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQgmCXK-iQDKf36Y0W-FkmpI3hvklXFAbACJaV7R956IZ6cWgbXs24Ge76-9JqqTXJVAn03mtleOzZW/pub?start=true&amp;loop=true&amp;delayms=3000',
#  'https://djx.xbtuykrn.top/',
#  'http://emailmarketing.locaweb.com.br/accounts/196090/unsubscribes/1/2315?emkt_c=1734793160&amp;emkt_v=c3R1ZGVudEBtdXAuY3o&amp;envelope_id=1',
#  'https://sites.google.com/view/agricole-05/accueil',
#  'https://bthome.w3spaces.com/index.html',
#  'https://bit.ly/3ZIqv0V',
#  'https://uspskaw.win/',
#  'https://gmxfreeemailinfo.weebly.com/',
#  'https://teamdiary.web.app/',
#  'https://efaxfastweb.weebly.com/',
#  'https://q-r.to/bfNGXY',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRwmrisHcoQxAEnmye84JhP4E4vk80wynoKRbVA_IYo1HGCfTlwHkS7FklwzP4EUnW93ViOQ8mo46Mb/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://l.ead.me/bfT4E1',
#  'https://olx-pl.nassiner.sbs/payment/35bb60ddda7c/millennium',
#  'https://thetollroads.com-fcqr.xin/',
#  'https://www.dropbox.com/scl/fi/6lttlcoh62rmgj5ycb954/Securely-sign-in-with-your-email-address-to-keep-you-updated..paper?rlkey=0xa1mujdrv89fopepfmpjh23v&dl=0',
#  'https://qrco.de/bfZWJD?trackingid=ljdJDKzWpS4oeYRy6snEi3FPtx589&amp;signature=newsletter',
#  'https://tinyurl.com/3j6vjwj7',
#  'https://orange.iobeya.com/s/download/resources/client-html-plugin/4.5.19.83329/public/',
#  'https://viewdocu560yah100us4c7bcs46ec56di9.github.io/s2025view89q02ce82ios8/ac0ios93yah',
#  'https://methamccklogui.webflow.io/',
#  'https://ledgerlive--app--live.webflow.io/',
#  'https://app-crypto-sso-web---cdn.webflow.io/',
#  'https://l.ead.me/brEew6',
#  'https://arkaskinclinic.com/',
#  'https://rhgu8rfhwrt3r.daftpage.com/',
#  'https://qrco.de/bfJWyw',
#  'https://e-zpassny.com-nkji.top/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRxElo2kQLIVrIBmLF3VJ-kjO-V8a4y8jFigJGDRbdhwdCzcQlJUyfYBRWBW4fWDES5fp9ZL_BeP2a_/pub?start=false&loop=false&delayms=3000',
#  'https://caso-4768.webcindario.com',
#  'https://www.org-ticketta.shop/',
#  'https://tinyurl.com/infodhs',
#  'https://qrco.de/bftC7v',
#  'https://cloud-a34c2.firebaseapp.com/',
#  'https://tinyurl.com/2pvbtcr4',
#  'https://tinyurl.com/bdvbpd4f',
#  'https://tinyurl.com/3tyd9brz',
#  'https://q-r.to/bfSQGV',
#  'https://pub-f3e7a7935198448e8052bd45a3a165f0.r2.dev/index.html',
#  'https://e-zpassny.com-ticketusd.vip/',
#  'https://ppczzg.webwave.dev/',
#  'https://index-support9.firebaseapp.com/',
#  'https://kukcoinloginus.webflow.io/',
#  'https://edavki-durs.web.app/',
#  'http://signin.microsoft.com.cerblos.ch/',
#  'https://02d772vb82.webcindario.com/worldwide/creditoption/',
#  'https://tx.hctraas.top/',
#  'https://ezpass.com-pvhw.vip/',
#  'https://lt27.de/vyzkRz',
#  'https://tinyurl.com/fvcfhgb',
#  'https://bit.ly/4cxQflK',
#  'https://tinyurl.com/2dc82sa3/?kiq=mjatep&amp;q=MTAzNDQ3Njs5MTA3OTEzOzIzMDk7MjsxMjIzOTsyMjsyMDI0LTExLTIwIDExOjU2OjQ5OzM7MTc7dTtTYXZlICQyNTAgb24gMS1EYXkgUGVybWFuZW50IEZhdCBSZW1vdmFsO1Nvbm8gQmVsbG8gQm9keSBDb250b3VyaW5nIDxnLnJvbWJhc3RpY29Ad29tZW53aXRoc3R5bGUuc2JzPg%3D%3D&amp;17-gmgovz=sdtqak',
#  'https://q-r.to/bfSu2b',
#  'https://qrco.de/bfITZG',
#  'https://ledgerliveapp-verified.webflow.io/',
#  'https://start-help--ledgre--sso.webflow.io/',
#  'https://txtag.org-txtagstorefronttksz.xin/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSLoP6dj-LWJSHy9T9qYCFbFQWpqcQFWsCEeIZtThKS7gbEUza79JGaRbfrWlHRb7J-ODYkN12i7Kzc/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://t.co/Af1mg5Uv8Y',
#  'https://auth-transf-wer-ro.weebly.com/',
#  'http://en-us-trezor.gorgias.help',
#  'https://aktualizaciazabezpecenia.web.app/',
#  'https://mondial-distributions.com/suivi-de-colis/265022126',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQ5NluMC7LW5l8FbYTp3PkYQJ9gyHAVyWi1BwhHXPfN16P45fack3DCbNQKAVjJDPMnFd6CEgDEn9Kq/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://e-zpassny.com-sjjb.xin/',
#  'https://helps-sso-treazor.webflow.io/',
#  'https://resolve.gfest.xyz/',
#  'https://qrco.de/bfkA9N?pageuser=pczcE',
#  'https://allegrolokalnie.pl-88834493.shop/',
#  'https://usps.com-tracking-usxxxm.cc/',
#  'https://bthomeinterneteuurjjsbka.weebly.com/',
#  'https://ezpass.com-ezis.vip/',
#  'https://prod-rd-10040.web.app/',
#  'https://jouturez.firebaseapp.com/',
#  'https://distribs-service.com/',
#  'https://mettmasklogon.webflow.io',
#  'https://ct-tzuw.top/',
#  'https://www.dropbox.com/scl/fi/s76ix3f5cadu4gtszjqbs/Securely-sign-in-with-your-email-address-to-keep-you-updated..paper?rlkey=hbpueoddf8gupubgfnwa4bnt4&dl=0',
#  'https://e-zpass.com-shlb.xin/',
#  'https://mountain-roasted-flavor.glitch.me/public/sure.htm',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRHIUJFp7R5TfVwpeDTLa38hMhroEfNKHJUfq6IeVoK22o1sf3q932Jy1IlI5PVrFol4hoiizSI6kRk/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://secured-pdf.s3.ca-central-1.amazonaws.com/statement.html',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQFU1UlscatPhA0chWHPNqqVcrM6mNUPxf_DA2NUQ8zQ2SvG1qPU4a2alwAQsKOB0OSJ8uZStBwcllt/pub?start=false&loop=false&delayms=3000',
#  'https://aave.at/aruba/',
#  'https://new.express.adobe.com/webpage/hXVyGPpCWIakQ',
#  'https://provinsol.webcindario.com/',
#  'https://pub-86bcfdb5c8f244d2bfc98c86780eea34.r2.dev/auth-mfa.html',
#  'https://bit.ly/3Bty2Z8',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSyyQGjEIoQc5Yd3dMRWKs7aSmh1Sh5_BC2e2vpAy4jRFf1-FWEd7M4dacCPMwvvDkWXf3MhW6gNYud/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://docs.google.com/forms/d/e/1FAIpQLSdq8BFvwC2vLFlA4Euvv-uEZ_RxH6kcYFZyXPweGK4P905Kgw/viewform?fbzx=6098199580820213457',
#  'https://pub-0261dee2350c4bc28e44dd341685214c.r2.dev/index.html',
#  'https://pub-ed64b968531c41d48fd7750f80f3c2f3.r2.dev/lifeelswarydydy1210.html#spam@uce.gov',
#  'https://meufundo.vercel.app/',
#  'https://l.ead.me/bfHHcr',
#  'https://pub-10457e7e6b8d42279b1152fa77e6eee0.r2.dev/index.html',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRdpj13-DHd25QfzAKagFAe6Rc7clXKhZ4Q3tktE9Wg5Mo91Qr3i18TuJWOCg7VvWi_09rDChN5kup2/pub?start=false&loop=false&delayms=3000',
#  'https://t.co/ChJSmRQ0uN',
#  'https://payfasttrust.firebaseapp.com/',
#  'https://bt-103431.weeblysite.com/',
#  'https://uytrhjnm.vip/',
#  'https://paytolllmeifn.vip/',
#  'https://new.express.adobe.com/webpage/Bk82q1DCzrEY3',
#  'https://attbellsouthcurrentlydesk.weebly.com/',
#  'https://generalitatdecatalunyainfo.weebly.com/',
#  'https://view.forms.app/swisspost091/enregistrement-en-ligne',
#  'https://pub-7f56102fe8444bdc84a34e2707b61390.r2.dev/zimbra_6546789976667767635.html',
#  'https://mygovv-online-website.web.app/',
#  'https://junowebmailupdatednextjdjdhf.weebly.com/',
#  'http://gedeki-jejate.zeabur.app/?.https://btemail.net/broadband/deals',
#  'https://etcbas.xin/',
#  'https://somoscorujasbraz.blogspot.com/',
#  'https://qrco.de/bfXnyK',
#  'https://tinyurl.com/2brxo9pc',
#  'https://auth--treezor-x--en-cdn.webflow.io/',
#  'https://pqzcdsh.us17.list-manage.com/track/click?u=9ef5660471c251c04277271fb&id=96644965a2&e=cee21189e8',
#  'https://disq.us/?url=https%3A%2F%2Fscript.google.com%2Fmacros%2Fs%2FAKfycbwGtBYI3-wTzL-CjyMEPEQOjH0OirBIqxKxezO2cr971WVF_VIZscGGUakiziN2TyqnGw%2Fexec&key=lNtGAOlHGzrmyUI3xIYc1g&452452',
#  'https://us-etcrw.xin/',
#  'https://babyliss-project.web.app/',
#  'https://startledgercomsetup.webflow.io/',
#  'https://pajem76668.wixsite.com/my-site-1/',
#  'https://e-zpassny.com.kmvu.xin/',
#  'https://shorturl.at/lLmjL',
#  'http://br.brasil108-6015.com.br/~fatur7488466/',
#  'https://l.ead.me/bfPV6E',
#  'http://43.153.207.103/v3/signin/identifier?dsh=S1577290132%3A1679418198747385&amp%3Bcontinue=https%3A%2F%2Faccounts.google.com%2F%3F&amp%3Bfollowup=https%3A%2F%2Faccounts.google.com%2F%3F&amp%3Bxrealip=35.203.252.146&ifkv=AWnogHc-Nd9VHpIzaJh8gM8oqtWosZqJmVsxzeL5B-E1zfm-3aI6Dkk7CSLaIhs9g_vX3mofjz-5vw&passive=1209600&xrealip=34.198.46.118&flowName=WebLiteSignIn&flowEntry=ServiceLogin',
#  'https://bit.ly/3Wl74JE',
#  'https://ezpass.com-eznj.vip/',
#  'https://my--trezor-suite.webflow.io/',
#  'https://micuenta-actualizacion.com/how/calcul.php',
#  'https://bc00.odoo.com/http/bcc78-atspace-co-uk',
#  'https://tinyurl.com/bdeysxt7',
#  'http://allegro.pl-oferta8544510.shop',
#  'https://tinyurl.com/2dphnn6b',
#  'https://agripacea.firebaseapp.com/',
#  'https://worker-morning-credit-d221.kosiv9212018.workers.dev/',
#  'https://t.co/K1sEGGOmGp',
#  'https://groucoles.web.app/',
#  'https://tollbillke.top/',
#  'https://campsite.bio/myaccount678',
#  'https://tiwofiana3.firebaseapp.com/',
#  'https://www.dropbox.com/scl/fi/lwm263q5qll9404ocmlm5/_-British-Telecommunication.paper?rlkey=ac57mwsk4feylze9mdjibm4kr&dl=0',
#  'https://cmi-clt.firebaseapp.com/',
#  'https://hshjshhjksjkuiqwui782.weebly.com/',
#  'https://43.163.85.254/',
#  'https://dllkmenqxbdeodifud.weebly.com/',
#  'https://qrco.de/bfILdz',
#  'https://t.co/i5Y81ugWlM',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQZ_3pfndCE_bMQUavS4E-gWk4WnJyLTW_FZpnwNhzv2jGEGLjRMW3hXKBffpKVJLT3GSe--bH5wMcl/pub?start=true&loop=true&delayms=3000&slide=id.p%3E',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQRAFEHnFHXX8itv4Gd1Qrc5RWjWuQkj8C2vO3ky-NFuSC1TwDVcwLTEBMXgcAERw6AXeANDgqjAow4/pub?start=false&loop=false&delayms=3000',
#  'https://ezpass.com-servz.xin/',
#  'http://allegrolokalnie.pl-pitbullpartyafterdarktour.top',
#  'https://metamaskxtension.github.io',
#  'http://zuza.stefek.szczecin.pl/Webmail/8/Webmail/webmail.php',
#  'https://l.ead.me/bfTIPN',
#  'https://wwi.avisos-gerente.app',
#  'https://ipfs.io/ipfs/QmVeJiRsi3uEXMkiyoHJcekBQXXtWgsWf9cSxHPmNpntNa',
#  'https://telstra-101740.weeblysite.com/',
#  'https://start--trezor-wallet-com.webflow.io/',
#  'https://learn-desk--m----ledgre.webflow.io/',
#  'https://istegdyehyd.w3spaces.com/ujdidiend.html',
#  'https://ledger-io-start-home-login.webflow.io/',
#  'https://l.ead.me/bfL5eo',
#  'https://leadgr-live--app.webflow.io/',
#  'https://shorturl.at/PL9Co',
#  'https://9400fr.weebly.com/',
#  'http://monirshouvo.github.io/fb_responsive',
#  'https://moiportal.info/3.html',
#  'https://e-zpassny.com-nldkz.xin/',
#  'https://pub-47cf88b9b6f343a5a501976be6adf17e.r2.dev/index.html',
#  'https://new.express.adobe.com/webpage/M42tfcITrYxlv',
#  'https://matsuniversity.ac.in/club.php',
#  'https://kuceeriqinlgen.webflow.io/',
#  'https://asterix-af2a5.firebaseapp.com/',
#  'https://bit.ly/3XUvWKD',
#  'https://bap-gmxnetsid-fb484500709fbec4a97ca840b16f82ef5785c42.square.site/',
#  'https://confirmsupport-accountverify-pagemanager.pages.dev/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTI2rvjSEewsC6BOciLmuRKU_DM2iLSWG7VVJzOFiNDHM_jPI2TwdZiRuflW9_eId4k1jvaQiXy4SLK/pub?start=true&amp;loop=true&amp;delayms=3000',
#  'https://hotlivee1.weebly.com/',
#  'https://uniquedesign.ma/?gclid=CjwKCAjw5pShBhB_EiwAvmnNV7ccoBbQEn4diVJyptHHT_Ifp8jjnQKD2ykHNc6t-oP4J93dN43DchoCkFgQAvD_BwE',
#  'https://qrco.de/bfMhPp',
#  'https://attmillttty.weebly.com/',
#  'https://pub-e9b1ffb3ecaf4416b4f40d71a6293787.r2.dev/movers.html',
#  'https://gudgsugd.weebly.com/',
#  'https://qrfy.io/p/irRyOtUIAd',
#  'http://43.134.167.94/v3/signin/identifier?dsh=S-117014669%3A1679418091725850&amp%3Bfollowup=https%3A%2F%2Faccounts.google.com%2F%3F&amp%3Bifkv=AQMjQ7QUzKK-KIlf323fzlkcY4jEM0w2RqRNXZPmECdS2cf5A1Sf0L7GtMB1p4OanV9FS-Q-l6HRsA&amp%3Bpassive=1209600&amp%3Bxrealip=107.178.232.242&continue=https%3A%2F%2Faccounts.google.com%2F%3F&xrealip=107.21.207.171&flowName=WebLiteSignIn&flowEntry=ServiceLogin&ifkv=AWnogHddYVtfjt0lwPG6mfbpq3eq2v9AR0JwZbzIoyMWvynfvYbogkvRXd5KEbXRUfL2bxeNRoIVmQ',
#  'https://intraf70f032cb.weebly.com/',
#  'http://surl.li/pxyjzg',
#  'https://central-basicdeployer.firebaseapp.com/',
#  'https://orgg-trezoloeein.webflow.io/',
#  'https://000000-reagan-login.weebly.com/',
#  'https://qrco.de/bfEVzbSCedgwSCFEFcv',
#  'https://kllllllla.weebly.com/',
#  'https://sijfjesfdeeye.weeblysite.com/',
#  'https://sites.google.com/view/adrinalokafor',
#  'https://tapk.it/attt010',
#  'http://allegrolokalnie.pl-323232.top',
#  'https://rebrand.ly/eizk5lh',
#  'https://0nlinel00k0utsupp0rt.weebly.com/',
#  'https://iagreewithattmailtermsofuse.weeblysite.com/',
#  'https://verification6556mailkjhgfdfgh876.weebly.com/',
#  'https://e-zpassny.com-ticketeou.xin/',
#  'https://bit.ly/3Cg6KFO',
#  'https://t.co/v9xDLsy6hV',
#  'https://appriverpasswordexp.web.app/',
#  'https://home-101376.weeblysite.com/',
#  'https://xfservicemail1.weebly.com/',
#  'https://outlook001.s3.us-east-005.backblazeb2.com/coihy.html',
#  'https://gracedivineeducation.ci/africa/',
#  'https://krakenbliogin.webflow.io/',
#  'https://bit.ly/3Yyx8DR',
#  'https://qrco.de/bfgL5m',
#  'https://mettamuskkloggenn.webflow.io/',
#  'https://e-zpass.com-rip.top/',
#  'https://csgo.zapbase.com/',
#  'http://allegro.pl-oferta98589984317.shop',
#  'https://new.express.adobe.com/webpage/fTkIP:',
#  'https://share.hsforms.com/1cevvrW9OSyaXZ6NtM6bjzQ4wxyi',
#  'https://pilgrimbank.weebly.com/',
#  'https://eu.jotform.com/app/250513941237352',
#  'https://5674784458.weebly.com/',
#  'https://sofmyspace.w3spaces.com/QmdzjbkzXMJ9PTbraZcemB/session-expiredzp.html',
#  'https://atttcurrently.wixsite.com/my-site',
#  'https://q-r.to/bfInvQ',
#  'https://q-r.to/bfJMrM',
#  'https://painted-beryl-babcat.glitch.me/weed.html',
#  'https://docs.google.com/drawings/d/1uqv2yrgm3I94D_GKhwbEDRWxnl9irz0etPVJ5CbKHXQ/edit',
#  'https://hjkl-db1e5.web.app/',
#  'https://lemon-luminous-sunstone.glitch.me/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTol5JtE-X-HtoUKn5FbquWW0Ow7kNQ18HeDM3EmdTCVwbRxneuSKX_Yin1fo-0nuAZZ9wVj6LWv5N1/pub?start=false&loop=false&delayms=3000&slide=id.p',
#  'https://att-104055.weeblysite.com/',
#  'https://bit.ly/Correos-ESP',
#  'https://b-105092.weeblysite.com/',
#  'http://ladiesimportados.com.ar/urait/contoo/',
#  'https://maasikas-emta-ee-ariklient.web.app',
#  'https://e-zpassny.com-vll.top/',
#  'https://servicio-suscripcion.web.app/',
#  'https://admin-pip-ka.firebaseapp.com/',
#  'https://official-ledgr-us.webflow.io/',
#  'https://broaddbannd.godaddysites.com/',
#  'https://l.ead.me/bfOo1P',
#  'https://pub-158a4ab7ad6e43209750eddbe930bddd.r2.dev/index.html',
#  'https://ezdrivema.com-xiiiya.vip/',
#  'https://qrco.de/bfI1DZ',
#  'https://ezriveks.xyz/',
#  'https://bit.ly/3y8kTDs',
#  'https://brc365phs.weebly.com/',
#  'https://ledger-l.memmserve.com/',
#  'https://pub-1778406e4fec4394901793111c187dd9.r2.dev/index.html',
#  'https://metamskchrm-extensin.webflow.io/',
#  'https://honke01.wixsite.com/my-site',
#  'https://lasdger-livapss.webflow.io/',
#  'https://pub-00a2ad7fd61a4ece8d6a0dd5f113b614.r2.dev/indx.html',
#  'https://mittmkxlogan.webflow.io/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQ6Ef6hJyLq6pp4VJC9opvtHBPmzqWre8MG-z0FCe7iu4kdMOXMttJ5jYx24Pve2HnEo4-ry06LJVOm/pub?start=false&loop=false&delayms=3000',
#  'https://us-etcrl.xin/',
#  'https://qrco.de/bfb9oa',
#  'https://bit.ly/4gY5Duk',
#  'https://welcome-trezo__en-cn.teachable.com/p/home',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQWdcDQs6wP29edgJcJmLJVNueiZWGQ-2gUuMVSXyJ0IWnxOsajmanYk-SmcKgA8qCkxQQO2xFLRExf/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://site-setup-success-9e84c.firebaseapp.com/',
#  'https://sunpass.com-sunpmko.vip/',
#  'https://e-zpass.com.bvcjiuek.cc/',
#  'https://l.ead.me/bfJngA',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTOvG6OXRLRS7N9LfQWwvDIsMK38hBSsHoz-Y85t-pypklQ0fwr7SOTis7fhrLQFX2YrlFt0UJdH2MK/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRvjTXiPpSWy5956OJhUSsCIJBJjHq9XwY9j_ZlJdBhBUCyprYGTTNfU9Pu4uryFoMzdmzTnSExuMTm/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://safecloudwebapp.web.app/',
#  'https://sso-secure--blocckfi-view-cdn.webflow.io/',
#  'https://eleoelswka.blogspot.com/?m&#61;0',
#  'https://e-zpassny.com-tollbillk.top/',
#  'https://l.wl.co/l?u=https://abre.ai/ei3z?userid=NL7MbJHZ',
#  'https://my-site-102790-105836.weeblysite.com/',
#  'https://q-r.to/bfFLhZ',
#  'https://takipcigir.com/login',
#  'https://qrco.de/bfSTPr',
#  'https://auths-m-start-ledger--cdn.webflow.io/',
#  'https://sosocr1.firebaseapp.com/',
#  'http://1108cb7.wcomhost.com/',
#  'https://allegrolokalnie.y0c9a81.shop/oferta/638e37f7-180e-4e24-b37d-dc42e9ce5f81',
#  'https://webmailexeculink21.weebly.com/',
#  'https://attservicesinc.weebly.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTDQoalzVfDnnoEvM4aGtzNfosWq168L9aOwNrNl2UzdU-jHmRyrKssNLIx7h17giHoVKDxxV9-gWQT/pub?start=true&amp;loop=true&amp;delayms=1000',
#  'https://vekimo9415-my-cheetah-website.site.builderall.net/',
#  'https://visioncenterss.blogspot.com/',
#  'https://lookerstudio.google.com/reporting/968034d3-c84e-45cd-8a1e-d85f7d8d5b1f/page/1M?s=vWMKUzNtElk',
#  'https://tinyurl.com/mr43hbyt',
#  'https://bit.ly/494NMOG',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTsHVH0s4C8CHd0zXjnEYnBCC0VoWImRNvFZnfr8fX_nB5OBkNFTobQ6Oya7-brq8jZoCFLfMeVZqju/pub?start=false&loop=false&delayms=3000&slide=id.p%3E',
#  'https://q-r.to/bfKJ9Z',
#  'https://logon-l-edgerlive.webflow.io/',
#  'https://q-r.to/bfKVZP',
#  'https://kjhgfgjug.weeblysite.com/',
#  'https://gstaad-saanen-lieferung.com/login/dpdch/',
#  'https://q-r.to/bfT4E1',
#  'https://bacpayee.contactin.bio/',
#  'https://bityl.co/S41Z',
#  'https://fpjcicqph.web.app/',
#  'https://instructionsforsubmittingfeedbackid1003837.vercel.app/',
#  'https://email-mweb-za.weebly.com/',
#  'https://serviceupdateinc.weebly.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTgca879kQqoZ06YmLGhZShzVFqXolPd6ir6xWniWRkFDHYdHNkdvJzJYDpj26_0xsIhsc-vQX8grGT/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://rackspacesecuring.firebaseapp.com/',
#  'https://rosieme.weebly.com/',
#  'https://wctei.weebly.com/',
#  'https://bakerysanemanetmsilnowsetready.weebly.com/',
#  'https://weeeeebbbbbbde.weebly.com/',
#  'https://q-r.to/bfXJgU',
#  'https://sosodo-a9b9a.web.app/',
#  'http://tinyurl.com/23y3cddw',
#  'https://usffhezpasscom.xin/',
#  'https://mypeachpass.com-djou.xin/',
#  'https://tunahrtjanzak9.web.app/',
#  'https://qrco.de/bfHEUa',
#  'https://cancelar-compra17mm.glitch.me/',
#  'https://bancaoccidente1.webcindario.com/?fbclid=IwZXh0bgNhZW0BMABhZGlkAasX-UE1pm0BHSuvg7a5qH90WNgIrNCdX2ebR5YfQ7JfSHUsaPPFVofAXmHPfwsH6bAtCQ_aem_MjKsnFsB_3Ky4Za_ -OToDA&amp;utm_medium=pagado&amp;utm_source=fb&amp;utm_id=120216174357140717&amp;utm_content=120216 174357290717&amp;utm_term=120216174357240717&amp;utm_campaign=120216174357140717&amp;sfnsn=wa',
#  'https://synconchain.surge.sh/',
#  'https://page-coinbase-pro.webflow.io/',
#  'https://q-r.to/bfOtON',
#  'https://q-r.to/bfJ2NL',
#  'https://qgdsgzeraqfqdfc.blogspot.com/',
#  'https://www.ethereuminfracon.com/m/aruba-it/',
#  'https://help-learnn-ledgre-ss.webflow.io/',
#  'https://vnmvbnmvbnmuiyuiyu56756756.pages.dev/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQiDILXMBhohGuzHJ_Xg_-2w99RnAJnsCtDd3QGI4WEafqKxQn89ZtvpSjRqREF7Z2atq2cQp0GxlJE/pub?start=false&loop=false&delayms=3000',
#  'https://tinyurl.com/2zjswx62?yOR=6LDIXZVLIo',
#  'http://dielotte.is-saved.org/.starters',
#  'https://identifiez-vous72.godaddysites.com/',
#  'https://qrco.de/bfYxSa',
#  'https://sweepstakes641.godaddysites.com/',
#  'https://technoindiagroup.com/secure-massage871600/confirm.html',
#  'https://mlhgbyza.vip/',
#  'https://qrco.de/bfJwDe',
#  'https://e-zpasrns.xin/',
#  'https://q-r.to/bfHqD6',
#  'https://etcme.win/',
#  'https://jeffjeff6.wixsite.com/webmail',
#  'https://mastercard.coqnoxzzhh.com∕psulhunln∕gujwbccrda∕ypmklc@ykkvnoxal.𝕜𝕞𝕙𝕦𝕝.cn/caonima=cqvwmsithr.co.jp/',
#  'https://secure.accountae.xin/',
#  'https://qrco.de/bfMTgY',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQX97MWAGMG98SH1uufq_NAJemAP8DIGB31Ai-gF8yxkwHuhUAbgG53etI4eKEa_vVyAIEqsL_AnBtt/pub?start=true&amp;loop=true&amp;delayms=3000',
#  'http://help-us-treazorr.webflow.io',
#  'https://tapk.it/bthsjsjk',
#  'https://securitycheck.verifyaccount.doubleclick.googleads.pagead.152-42-165-106.cprapid.com/iquwhesaibfiasf=quowhjsajkbfa',
#  'https://110b9b7.wcomhost.com/',
#  'https://l.ead.me/bfMLpo',
#  'https://indd.adobe.com/view/dee27d79-7995-4885-a9a4-16d3d55c6cd7',
#  'http://tiny.cc/0vy3zz',
#  'https://google-l-edger.webflow.io/',
#  'https://giapoksx.top/',
#  'https://ezpass.cscusa.win/',
#  'https://hagatljabgalluam.blogspot.com/',
#  'https://flashipa.com/',
#  'https://e-zpassen-ny.xin/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQPzKmLSao3H1plwOQ9rQS11fE5kcKFWtIB8eIZ24_U3-y7v2Ld0jRLKT4J5UxN-RoCHSiquCjzHXfb/pub?start=true&amp;loop=true&amp;delayms=3000',
#  'https://fxtkbszy.top/',
#  'https://sunpass.com-ticketeue.xin/',
#  'https://ezpass.com-ezno.vip/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSTZ_qYNH6kTavrxkJ8D1FS7JjgTU_SXqyNWpL6-KAyoloOPoO6s53WH1QzBEFnW9iI4Qi-6gtWmNno/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://swxzygjq.vip/',
#  'https://app-blokfi-sso-cdn.webflow.io/',
#  'https://l.ead.me/bfIIid',
#  'https://culturafocus.com.br',
#  'https://delivery-dhlmanage.firebaseapp.com/',
#  'https://leadger-live-luogin.webflow.io/',
#  'https://pub-dcd992e051224d49bc4d37f504eeac15.r2.dev/wsom.html',
#  'https://qrco.de/bf6SFF',
#  'https://sites.google.com/view/presenteasunxota',
#  'https://docs.google.com/presentation/d/15U2Vp2j_VEDj2v53HVwybm7AZbejy4Cy29PCwkBa6qY/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://domappcheckomeg30.web.app/',
#  'https://idolink.com/ovo',
#  'https://bit.ly/4dAWw0c',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQz4qV8k_KsotJr7m65PwperALcAnAzqyCNvFgVOD-kLx93IQ8bZ6VWiT70Wrdr7NP3ZcG_pONFiVcS/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://s-crypto-ssod---cdn.webflow.io/',
#  'https://t.co/glE7StbwLR',
#  'https://e-zpass.com-etcqzf.vip/',
#  'http://179.43.150.53',
#  'https://nnfems.com/Webmail/68/Webmail/webmail.php',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQp78sLf2D12BFsVU4F6JW81ibZWPEThJ2d8BAQxHH6-te3YeESTW9N2rgYVA4VNExib168cfAl7X3-/pub?start=true&amp;loop=true&amp;delayms=3000&amp;slide=id.p',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRB4s9nEGfi5Xux__TXnqbWdZWh1_E8EIUcagKpggyATFquKa6J8CAbxL9VahqLvdARO2ylO98t0tFj/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://q-r.to/bfI2et',
#  'https://secure-app--coinbasepro--cdn-home.webflow.io/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vR_fqzmGIJbeH7WgvOD_5p2WxwUy8dj-N6FipNPOAKQV8tlffhryzAskgGUgxR-lmwcPdOrmJ5uXxx5/pub?start=false&amp;loop=false&amp;delayms=3000&amp;slide=id.p',
#  'https://reagan-105119.weeblysite.com/',
#  'https://usdqhezpasscom.xin/',
#  'https://bit.ly/3SS6fqQ',
#  'https://mygoodtogo.com-pzao.vip/',
#  'https://activationpanel.net/login.php',
#  'https://credit-bdv03.webcindario.com/',
#  'https://ezpassmn.com-tollbillbwz.xin/',
#  'https://security-check.start.page/',
#  'https://hafddarmm.blogspot.com/',
#  'http://allegro.pl-oferta4059941.shop',
#  'https://invoice76542dfb.myportfolio.com/',
#  'https://allegrolokalnie.0v8a71-41244.shop/',
#  'https://academi-arena.web.app/',
#  'https://qrco.de/bfNp3N',
#  'https://geaqrgaq-d.blogspot.ch/',
#  'https://bit.ly/3O6rGBZ',
#  'https://meine-sicherheitshinweis.web.app/',
#  'https://paxful-ng.vercel.app/',
#  'https://com-vgic.top/',
#  'https://astroingboy.web.app/',
#  'https://sebat-dhl.blogspot.com/',
#  'https://jsnectrese.web.app/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSdmn3UGu5YzT8ICcpv5lpEoIZD1pRx6gy4KYiUThDzeISqCaQqCTgMFJObwV-7LlSKBMcWOnI25tnY/pub?start=false&amp;loop=false&amp;delayms=3000&amp;slide=id.p',
#  'https://sunpass.com-tollbilllu.xin/',
#  'https://firebasestorage.googleapis.com/v0/b/uuiiyytttyyuuiui.appspot.com/o/yurrdcbinx.html?alt=media&token=4b4a49fb-08b8-48cc-b071-f08d2d52fde9',
#  'https://t.co/q2veKOlEqA',
#  'https://q-r.to/bfRv2v',
#  'https://vnreintka1.firebaseapp.com/',
#  'https://e-zpassny.com-tollbillmhg.xin/',
#  'https://server-107618.square.site/',
#  'https://new.express.adobe.com/webpage/ZPU0AXhDap42B',
#  'https://dm640746a23c.myportfolio.com/',
#  'https://humdrum-periodic-web.glitch.me/jewel.html',
#  'https://success-ionos.serveirc.com/login.php',
#  'https://telstra-103510.weeblysite.com/',
#  'https://tecim64990.wixstudio.io/my-site',
#  'http://tinyurl.com/9876YUHJKH?bradesco',
#  'https://bit.ly/49Y5ns5',
#  'https://bryanapps2.club/',
#  'https://shorturl.at/hkR7p',
#  'https://vesrsionpluspropre.web.app/',
#  'https://hotm.art/vq1t4G',
#  'https://alleqro.16357021.xyz/',
#  'https://tinyurl.com/3bhjamdc',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSzKeWOBmmyeXp4aa8V6ddToSjk1ECDXxsq0FDZcqyo0ygYA6ITwObmCDrbnPUQNL1t-uhzgTpBKnd9/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://t.co/AYmwzzyZph',
#  'https://case-id-1000228260613.counselschambers.co.uk/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQ-V1dr6B1iGJslqUv_3TV-Odj1Bks9AckzgdRRutRS5aQcA4xWzHIXHoeblKZfpqoE4emUAx1Gx57f/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://us17.list-manage.com/survey?u=ddc7fbbbba66c948553aa1059&id=f2aa1f236f&e=*|UNIQID',
#  'https://t.co/2cqcjxMRPR',
#  'https://metamakknlloiun.webflow.io/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vT8sB3ViQesG9yS5w-X3c2Ik90J5QvPwivl7fYUcMZO49nxVHKz-kCgTV8PElDJ4Xqkw7-v6hevCE5z/pub?start=false&loop=false&delayms=3000',
#  'https://www.shorturl.at/bLjWj',
#  'https://ezpass.com-sjqu.vip/',
#  'https://l.wl.co/l?u=https://t.co/8rtzAPqE6l',
#  'https://pub-5692101760be4ecaab12379398d9297d.r2.dev/index.html',
#  'https://pub-682ad3b65d944376b919745aae3c56d4.r2.dev/document3.html',
#  'https://beta-track.firebaseapp.com/',
#  'https://pub-ced0b878a6704f14b7861696c70bb511.r2.dev/index.html',
#  'https://pibrowseractivation.pages.dev/',
#  'https://pub-24b8f6d2fffe4a0087038967ff4b7e3f.r2.dev/INBOX.html',
#  'https://resolverauthpanel.firebaseapp.com/',
#  'https://new.express.adobe.com/webpage/K89O6E5DG2YLl',
#  'https://zgi3258m.paperform.co/',
#  'https://iqsewyus.top/',
#  'https://qrco.de/bfIHJ1',
#  'https://qrco.de/bfXAAS',
#  'https://sites.google.com/view/yahooattmail0876tyjh/home',
#  'https://873482418024-29jungspl.start.page/',
#  'https://shorturl.at/R6zIH',
#  'https://bit.ly/3Aed14e',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRQvb6KePnetnbzClvnxDNm73qUJU8hHtKbj9IILaAQHSEWQjEW5zOu4FJXBSs3SZltjRNAsjGIPja7/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://gemigini-logine.webflow.io/index.html',
#  'https://hdn.ctp.mybluehost.me/xZF87wT0rcpA7vVOBbNs',
#  'https://potsvfoi.xin/',
#  'https://e-zpassny.com-bbf.vip/',
#  'https://graphlinq-chain.webflow.io/',
#  'https://forms.app/form/6654d473033ee1f8085e746e',
#  'https://kjdjjkdour.weebly.com/',
#  'https://supercaracol.ar/wp-content/plugins/akismet/dgt/ddgg/cold/appro.php',
#  'https://abv-102633.weeblysite.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRJV6w01EqugNDAezdU8bNbt51tWUac79wuYY9btADwdcQgceV00Zh1lT3OQBwD39fp6Uc9ewtb06xe/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://away.vk.com/away.php?rh=7ea9d089-aac9-45e0-83e7-91853370b42b',
#  'https://about.me/validmailboxdata',
#  'https://l.ead.me/bfIbvA',
#  'https://q-r.to/bfSRY7',
#  'https://wisconsindot.gov-etcmv.xin/',
#  'https://new.express.adobe.com/webpage/capdmtgPCGsQ6',
#  'https://pub-56bd9143f05d4100b605783bdc43dfff.r2.dev/upgrade24date.html',
#  'https://sites.google.com/view/weiterlogweb/home',
#  'https://q-r.to/bfInjL',
#  'https://etcaet.top/',
#  'https://lgoin--kuccoin.webflow.io/',
#  'https://mail-104478.weeblysite.com/',
#  'https://shorturl.at/M7amK',
#  'https://auth---p-start--totezor.webflow.io/',
#  'https://a-teamallbills.vev.site/billmail',
#  'http://pub-ef47dfdc85ad463a911b6bde06661e80.r2.dev/inbox.html',
#  'https://sites.google.com/view/newestattloginpage2025/home',
#  'https://txtag.org-txtagstorefrontbgr.xin/',
#  'https://sites.google.com/view/bttogonew/home/',
#  'https://uw0xub.webwave.dev/',
#  'http://tinyurl.com/29ankbl6',
#  'https://bit.ly/3C67RTD',
#  'https://bit.ly/4b3wFgD',
#  'https://27653fd738hej.ukit.me/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSFEIS2vXIf85d0XbKAyR12ruNF_CjJ1JdEDEkFzghb4MoiINlJ64h4uNZ_AnR34XMjc4AiQ-FlZ002/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://ledger-io--start.webflow.io/',
#  'https://perso8764002.wixsite.com/source-bonheur',
#  'https://l.ead.me/bfMJU6',
#  'https://mailattprivate.weebly.com/',
#  'https://gmxdeinfo.weebly.com/',
#  'https://rpu4sc.webwave.dev/',
#  'https://sp973634.sitebeat.crazydomains.com/',
#  'https://btconnect-103876btconnectmail.weebly.com/',
#  'https://coinbaeprcomlogin.godaddysites.com/',
#  'https://3-64-147-162.cprapid.com/ro/update6.php?x7yrc6ybi5a9afguncsr',
#  'https://lwkqmanseyrdusidffg.weebly.com/',
#  'https://q-r.to/3n4fqf6gpx8d',
#  'https://www.dropbox.com/scl/fi/c8twsojodfr9jsoppchek/BT-Voice-Message.papert?rlkey=6dsdghmmxleplpwgurm8l2npp&dl=0',
#  'https://thibaudatvalerie1.wixsite.com/my-site?user-agent=Mozilla/5.0',
#  'https://paytollcvhi.vip/',
#  'https://l.ead.me/bfEFYq',
#  'https://docs.google.com/presentation/d/1fnRyFBpeFSaNrmI7DjD-3ZeYeZIAS2iRSpw-MtEGE_g/pub?start=true&amp;loop=false&amp;delayms=3000',
#  'https://pub-8cdf3294ae6b41b29a9cda26deed6232.r2.dev/exel.html',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQzhdI2K4cagrG92sl_lHHVobo2LkfdMnL2Mm_sdtnHJvwW4T-i863UmdUWJbrnk8l14xWWhu9DBZ-U/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://ezpass.com-ezpasv.vip/',
#  'https://tinyurl.com/4mjruvc6?nLt=qia4F8b4jS',
#  'http://tinyurl.com/3t4bapkc/',
#  'https://dktraders.in/gallery/',
#  'https://driveezmd.com-zce.xin/',
#  'https://attmailcenter-2198.weeblysite.com/',
#  'https://northwestelnetemai.wixsite.com/my-site',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRa7f3EDabA6Y6qN0FoDYfNss9atm5tlUnrobsv1RQuNz4djTuPqzo6VrQPQfxfXs9KVcz0GjBc_-XB/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://usps.paytollivux.vip/',
#  'https://l.ead.me/bfHe3f',
#  'https://qrco.de/bfS4NZ',
#  'https://qrco.de/bfSKja',
#  'https://auto1matiquelaposte.weebly.com/',
#  'https://t.co/zMxQdimMSP',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTj97f0YP7ddnT8KwUKxup3_6vHyA8PJVqII2_-tSL5EanFkXZISphC_92xs7O5jRSFXdsO34hD-MyL/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://bafybeigu6ojg4bql62wjvn7gumorfpzfqw43erg55yla3t35bztr6gluga.ipfs.fleek.cool/Session%20Expired.html/?noc@digitalocean.com',
#  'https://docs.google.com/presentation/d/e/2PACX-1vRW2BYhaBfB2Ensec_wCYk6uHv6xoVL670CoXuz3LYK4wcE0yYzGmwjo9SI5_9CVrnwqGwjGxZelLma/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'http://43.156.237.181/v3/signin/identifier?dsh=S-603914289:1680051879592988&amp;continue=https://accounts.google.com/?&amp;followup=https://accounts.google.com/?&amp;ifkv=AQMjQ7Sg3Mmp4O1qi_2RshqAgm2y51bbOV7vRDB6bU4Ds7qHZfLsAj8YsPflNjSQi-1RepEL8zhfpQ&amp;passive=1209600&amp;xrealip=107.178.232.171&amp;xrealip=217.138.252.164&amp;flowName=GlifWebSignIn&amp;flowEntry=ServiceLogin&amp;ifkv=AQMjQ7Rynpr65Ob3WK6404fudpEoMHkHZIqNZZGlckMRGgInpro_WWUu1Ra9NALWZP5xpVhyl1M3Cg',
#  'https://www.dropbox.com/scl/fi/oilq1wwi8dprh269ugmrr/BT-MAILBOX-NOTIFICATION.papert?dl=0&rlkey=m85yuefikfqy7r49g6m94e04p&st=ofirwcp9',
#  'https://celeponcelopoijo.github.io/cleansswapaces/come/index.html',
#  'https://account.booking.com/sign-in?op_token=',
#  'https://e-zpass.com-etcqlt.vip/',
#  'http://kaywa.me/Hg0ZI?profile=870765',
#  'https://com-qwyd.xin/',
#  'http://q-r.to/beJ0nUCefgwsegerhberhsvsdg',
#  'https://tinyurl.com/shkpufkf',
#  'https://q-r.to/bfF0IM',
#  'https://msm-sonnenschutz.at/account/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vT7cWcjuXAwCMHQMm7EwdHDu69dmhxehwVpaV9N442dqGWTDb0IzaEEhK6PRHhMZQZvYOgmNcyZ4oXT/pub?start=false&loop=false&delayms=3000#slide=id.p',
#  'https://l.ead.me/bfTfyq',
#  'https://survey123.arcgis.com/share/4f1becd634a34e9481d6ffd79d771a62',
#  'https://dappwalletauth.firebaseapp.com/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQc6KHRkHo4VrNa8C9J9_jrJVmS-u-m2KMAeKVclTE_OEzecljDYl_WJ_6tC3u0Yv1QmWBCqhiuJY5M/pub?start=false&amp;loop=false&amp;delayms=3000&amp;slide=id.p',
#  'https://new.express.adobe.com/webpage/T30sQ8mPYMiuy',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTJntOLA7Ws1z7KchgDwfJ__dZ60MYwFl4kYNoyTgs9Yh1dCdmXly_UvKg-rfwkOaIpPFDbyZK-dLs-/pub?start=false&amp;loop=false&amp;delayms=3000&amp;slide=id.p',
#  'https://app.rededigitalchevrolet.com.br/login',
#  'https://www.dropbox.com/scl/fi/f34cqrxsmlz99g9wcp0t5/BT-ID-Administrator.paper?rlkey=k0tqvjy0rixnxdiw8tqmw6wmb&dl=0',
#  'https://pub-ece32ef2b893469189534a6e7fdff32f.r2.dev/index.html',
#  'https://pub-19adc4e57069479caeb411abf55506e5.r2.dev/1616pppp0910p.html',
#  'https://q-r.to/bfVkll',
#  'https://f.yourl.jp/d7072995/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vQ0FCIWNWVJfPgGPyBt92UFElF-PSdvd8bzMnMermQ2WIjrYumv5lWDxLK5rMFSkO73qVfhDI_xqLbQ/pub?start=false&amp;loop=false&amp;delayms=3000',
#  'https://ezpass.com-ezxa.vip/',
#  'https://finishingschool.aikatechnology.com/',
#  'https://q-r.to/bfNjMP',
#  'https://mmm.page/broadbadbt/bt',
#  'https://orangefrvousidentifie.ukit.me/',
#  'https://e-e-team-106349.weeblysite.com/',
#  'https://dwnload--leidgrelive.webflow.io/',
#  'http://43.153.207.103/InteractiveLogin?continue=https://accounts.google.com/?&amp;followup=https://accounts.google.com/?&amp;passive=1209600&amp;xrealip=107.178.237.20&amp;ifkv=ASKXGp3X73PSFTdua0tm2qpyX3p4xlCUQrEzHLRluuBUrrIhgzc-oWMc2tMaBQzxdHC_FIEJwWG7eg',
#  'http://allegrolokalnie.oferta-3439076.sbs',
#  'https://pub-dad5144323dd4384b4198a74448f2cc7.r2.dev/index.html',
#  'https://lepjistruq.weebly.com/',
#  'https://qrco.de/bfKAhg',
#  'https://tbhzmpqcxkgyv.top/',
#  'https://jhgfdgf774.w3spaces.com/',
#  'https://103.189.235.156/~ddi1/',
#  'https://docs.google.com/presentation/d/e/2PACX-1vSRNA-eaaxrY7PUHufqlm3Gv7NrVwDjPFsxLIoosefUL7rxuExh2piUR5fu1HBT9XAfqubcnA5pHp1V/pub?start=false&loop=false&delayms=3000&slide=id.p',
#  'https://webledggeerlivedownload.webflow.io/',
#  'https://bit.ly/4di73xD',
#  'https://bit.ly/3VMqo2e',
#  'http://caracasmateriais.blogspot.com/',
#  'https://qrco.de/bfVlDC',
#  'https://help-ttrzsstarth.gitbook.io/us',
#  'https://nnhujjsbegwsd.weebly.com/',
#  'https://e-zpassny.com-tiznqa.xin/',
#  'https://e-zpassfs-ny.xin/',
#  'https://pub-dfa5dc9b1b264e89b08343cf0a26450b.r2.dev/mod.shtml#aWZ1Y2tlZEB5b3VybW9tLmNvbQ==',
#  'http://43.156.0.130/v3/signin/identifier?continue=https://accounts.google.com/&amp;followup=https://accounts.google.com/&amp;ifkv=AYZoVhdc2mRRYuDyXjbPl3jZIIW0hNltZQLLmFu7oP0XL-_VqogfhrNjy5dFlbYYa8uOUl7aCXD0UA&amp;passive=1209600&amp;flowName=GlifWebSignIn&amp;flowEntry=ServiceLogin&amp;dsh=S-1207429424:1694424721805529&amp;theme=glif',
#  'https://repairsharelementfr.firebaseapp.com/',
#  'https://apptuts.bio/detalhamentoluiza?gclid=EAIaIQobChMI-qLX56Gx_QIVkxXUAR0EmwYNEAMYAiAAEgJJ9PD_BwE',
#  'https://docs.google.com/presentation/d/e/2PACX-1vTZDeFnrYkWEqM7WCZyqg5zdxzRylW0QdUiEcGjP0mjKhfoimV_Z5XPL51gVPjvbm0Zm1S_37WOKyPS/pub?start=false&amp;loop=false&amp;delayms=3000',
#  ...]

# %%
df_benign.head()
# Out:
#    rank            domain
# 0     1        google.com
# 1     2     microsoft.com
# 2     3           mail.ru
# 3     4  root-servers.net
# 4     5      facebook.com

# %%
benign_urls = ['https://' + d for d in df_benign['domain'].sample(n=dataset_count, random_state=42)]
benign_urls
# Out:
# ['https://o-pa.org',
#  'https://sales-crowd.jp',
#  'https://regiontehsnab.ru',
#  'https://helpnet-es.net.br',
#  'https://fidh.org',
#  'https://flashpoint.io',
#  'https://alberto.com.ph',
#  'https://accidentrescue.in',
#  'https://uludagsozluk.com',
#  'https://8k8app4.com',
#  'https://otzyv.eu',
#  'https://freesoft.org',
#  'https://tierschutzverein-deggendorf.de',
#  'https://ya-trader.com',
#  'https://belowthebelt.com',
#  'https://audar-info.ru',
#  'https://apmdns.com',
#  'https://izlenseflpalt27.shop',
#  'https://centerforinquiry.net',
#  'https://wexer.com',
#  'https://skybbs.biz',
#  'https://fundex.exchange',
#  'https://premierpluss.com',
#  'https://airpho.com',
#  'https://3ctch.com',
#  'https://pgsoftwallet.com',
#  'https://careerindex.jp',
#  'https://cyim.com',
#  'https://piksel.tech',
#  'https://playpokerogue.com',
#  'https://humoronline.com',
#  'https://mxptint.net',
#  'https://zelesta.de',
#  'https://julius-randle-az.com',
#  'https://chinhosting.com',
#  'https://vegaformazione.it',
#  'https://lustfilms.com',
#  'https://suss.edu.sg',
#  'https://dbkpop.com',
#  'https://hosting-tanio.info',
#  'https://traditionsfirearms.com',
#  'https://namehero.net',
#  'https://colsecor.com.ar',
#  'https://oocllogistics.com',
#  'https://uslcentro.toscana.it',
#  'https://aromajoes.com',
#  'https://oxbridgeacademy.edu.za',
#  'https://vodkakasino1.online',
#  'https://torrentinvites.org',
#  'https://goodplacevn.com',
#  'https://my-server6.co.za',
#  'https://clcfrance.com',
#  'https://photohito.com',
#  'https://melmac.space',
#  'https://trkangalavrupa.com',
#  'https://4kbet3.com',
#  'https://solanaflix.com',
#  'https://mustedu.com',
#  'https://vulcanrussiaslots.com',
#  'https://nxondemand.com',
#  'https://rutor.org.in',
#  'https://usehurrier.com',
#  'https://apmt.ru',
#  'https://xeggex.com',
#  'https://ocinequadernillos.es',
#  'https://wcvb.com',
#  'https://vastavnewslive.com',
#  'https://health.gov',
#  'https://poddtoppen.se',
#  'https://medmix.com',
#  'https://fotograf.de',
#  'https://woddd.mom',
#  'https://lucky88.com',
#  'https://mgmotor.eu',
#  'https://spravka-moscow.net',
#  'https://volhovec.ru',
#  'https://remia.com',
#  'https://uniqman.com.tw',
#  'https://singidunum.ac.rs',
#  'https://taipan77vietnam.xyz',
#  'https://q-tec-dyn.de',
#  'https://linestep.jp',
#  'https://bestblastgames.com',
#  'https://wsbdgef.com',
#  'https://farodiroma.it',
#  'https://linenmaster.net',
#  'https://grandvision.io',
#  'https://mtcbroadband.net',
#  'https://ufcfan.org',
#  'https://arunjain.net',
#  'https://oncomcast.com',
#  'https://paranormal-ch.com',
#  'https://africanvibes.com',
#  'https://jblearning.com',
#  'https://plutto88sawer.store',
#  'https://futbolparaguayotv.xyz',
#  'https://legionmasters.com',
#  'https://amity-motors.com',
#  'https://bigfang.tw',
#  'https://nafin.com',
#  'https://ticketspice.com',
#  'https://rozklad.com',
#  'https://julienslive.com',
#  'https://ikwilvanmijnautoaf.nl',
#  'https://high25-playback.com',
#  'https://cardmarket.com',
#  'https://tuincentrumoverzicht.nl',
#  'https://nfcihospitality.com',
#  'https://krassever.ru',
#  'https://americangolf.com',
#  'https://1wxscr.com',
#  'https://gironasoft.info',
#  'https://kreando.ch',
#  'https://otakuhouse.com',
#  'https://signicat.dev',
#  'https://dolphin-ip.online',
#  'https://chalk247.com',
#  'https://mandian.com',
#  'https://fizz.ca',
#  'https://attackcdn.com',
#  'https://flirtlocal.com',
#  'https://merrypom.it',
#  'https://ringtonewave.com',
#  'https://lakutotomaju.com',
#  'https://human-d.co.jp',
#  'https://prostitutkirest.com',
#  'https://southboundbride.com',
#  'https://irpinianetcom.it',
#  'https://mnnu.edu.cn',
#  'https://isppro.net',
#  'https://mihandarya.ir',
#  'https://storm-chan.com',
#  'https://f05fu5oxsw.com',
#  'https://coop.net',
#  'https://bluetarp.com',
#  'https://cfan.com.cn',
#  'https://outsideresource.com',
#  'https://freemedia.win',
#  'https://vilhelmina.se',
#  'https://dosbithost.com',
#  'https://casino-1xbet.bike',
#  'https://radioplayer.fr',
#  'https://fitnowinc.com',
#  'https://sabachatroom.com',
#  'https://sam-isp.net',
#  'https://hqporn.pics',
#  'https://smiles.com.br',
#  'https://theannaedit.com',
#  'https://karst.edu.cn',
#  'https://bankertotocountry.xyz',
#  'https://ciechanowiec.info',
#  'https://felixgray.com',
#  'https://grossetonotizie.com',
#  'https://xvids.wtf',
#  'https://almapatika.hu',
#  'https://brighthiveinnovations.com',
#  'https://wcmu.org',
#  'https://adnkronos.com',
#  'https://ate.cn',
#  'https://www.gov.qa',
#  'https://getjoystick.com',
#  'https://honeybot.us',
#  'https://ambafrance.org',
#  'https://copychief.com',
#  'https://proautoforum.ru',
#  'https://thulium.com',
#  'https://netterimages.com',
#  'https://wiserapp.co',
#  'https://ddnsguru.com',
#  'https://spooferpro.com',
#  'https://chomered.com',
#  'https://volunteersguild.org',
#  'https://teebweb.org',
#  'https://zalando-lounge.no',
#  'https://findtheneedle.co.uk',
#  'https://costcotireappointments.com',
#  'https://thewoodveneerhub.co.uk',
#  'https://amateurporn.me',
#  'https://sisgel.com',
#  'https://ubuy.cm',
#  'https://delonima.lol',
#  'https://exiv2.org',
#  'https://macmillan.org.uk',
#  'https://downloadhub.moi',
#  'https://moon-age.com',
#  'https://88chip.net',
#  'https://usfinanceinsider.com',
#  'https://membersecurelogin.com',
#  'https://tunepage.ru',
#  'https://twstay.com',
#  'https://awsdns-cn-23.biz',
#  'https://fanslia.com',
#  'https://jkplanet.jp',
#  'https://kineoadapt.com',
#  'https://ybonline.co.uk',
#  'https://thevibemultibrand.no',
#  'https://l2l.com',
#  'https://kaunoklinikos.lt',
#  'https://maxai.me',
#  'https://simplify.jobs',
#  'https://netpop.app',
#  'https://widgetwhats.com',
#  'https://jbhe.com',
#  'https://soff.uz',
#  'https://navymutual.org',
#  'https://eastcoastinjury.com',
#  'https://fogcreek.com',
#  'https://flixbus.fr',
#  'https://udirny.cz',
#  'https://lesinrocks.com',
#  'https://3305.ru',
#  'https://kiwi.no',
#  'https://plant-world-seeds.com',
#  'https://msaludjujuy.gov.ar',
#  'https://asusplus.bg',
#  'https://langgam.id',
#  'https://maxyield.ai',
#  'https://cwst.com',
#  'https://autoscout24.se',
#  'https://omnimed.com',
#  'https://chocololo.pl',
#  'https://kombo88mb.com',
#  'https://dmmserver.com',
#  'https://travos.ro',
#  'https://eldorado-officialsite.vip',
#  'https://qawmimadrasa.com',
#  'https://atmiya.edu.in',
#  'https://zhongzilou.com',
#  'https://julianatoren.nl',
#  'https://fwcdn1.com',
#  'https://hinweisgeber.pro',
#  'https://stepmap.de',
#  'https://mathinfo.tn',
#  'https://algorithmia.com',
#  'https://taxis-g7.com',
#  'https://onpravaay.com',
#  'https://jqsupertech.com',
#  'https://060222.com',
#  'https://ytadalafil.com',
#  'https://malagasy.com',
#  'https://casinoz-cat-club.buzz',
#  'https://exclusivemi.com',
#  'https://edimakor.net',
#  'https://dbkg.de',
#  'https://salzburg.com',
#  'https://the-news-desk.com',
#  'https://bluevelvet.co.kr',
#  'https://solteros50.com.mx',
#  'https://inhibrx.com',
#  'https://5dimes.eu',
#  'https://mcsweeneys.net',
#  'https://greatdealsindia.com',
#  'https://rabbit.tech',
#  'https://tera4dk.com',
#  'https://front-san.com',
#  'https://interdomain.es',
#  'https://corrieredisciacca.it',
#  'https://molnija.shop',
#  'https://ofimarket.pe',
#  'https://apnafurniture.pk',
#  'https://forceusercontent.com',
#  'https://elephantsolutions.net',
#  'https://jensenresearch.com',
#  'https://passiveaggressivenotes.com',
#  'https://unique.gm',
#  'https://orlandodiocese.org',
#  'https://neuro-nix.space',
#  'https://grubygarage.com.pl',
#  'https://appnexus.net',
#  'https://cryptoclicks.net',
#  'https://carlog.com',
#  'https://rshub.io',
#  'https://wmsl-uk.com',
#  'https://benditoguia.com.br',
#  'https://wavedns.net',
#  'https://kiss918menang.com',
#  'https://rbinternational.com',
#  'https://gador.com.ar',
#  'https://programaacelera.com.br',
#  'https://tuyengiao.vn',
#  'https://kravmaga.com',
#  'https://snrt.ma',
#  'https://ivermectinesd.quest',
#  'https://emvisesa.org',
#  'https://incms.vc',
#  'https://dreamlite.io',
#  'https://surebox.icu',
#  'https://xiongmaoyunzz.wtf',
#  'https://clancymoonbeam.com',
#  'https://novindc.net',
#  'https://tevi.net',
#  'https://pall.co.uk',
#  'https://ppv.com',
#  'https://crm-kozuchi.com',
#  'https://sanctuaryworld.co',
#  'https://charttrack.com',
#  'https://bloggerheads.com',
#  'https://clover.host',
#  'https://caimogu.cc',
#  'https://rovehotels.com',
#  'https://thecreativecurator.com',
#  'https://sportsbettingdime.com',
#  'https://raleighrealtyhomes.com',
#  'https://adctrl.com',
#  'https://ldz.lv',
#  'https://999kkg.biz',
#  'https://justsee.co.in',
#  'https://aaisharai.rocks',
#  'https://bncservices.com',
#  'https://dndnha.cam',
#  'https://tintup.com',
#  'https://iiozb.shop',
#  'https://office-converter.com',
#  'https://tradetracker.com',
#  'https://topcon.co.jp',
#  'https://gazetavv.com',
#  'https://ands.org.au',
#  'https://ul.to',
#  'https://palladiumpraha.cz',
#  'https://webshop.pl',
#  'https://irodakomplex.hu',
#  'https://fivebackgift.com',
#  'https://dirty.ru',
#  'https://rebeliq.com',
#  'https://chefette.com',
#  'https://pxgametw.com',
#  'https://sieciaki.pl',
#  'https://cadastro.io',
#  'https://nakamoto.tokyo',
#  'https://dreambigsweeps.com',
#  'https://kazvek.com',
#  'https://nextjs.org',
#  'https://demo.ly',
#  'https://azurlane.jp',
#  'https://barobill.co.kr',
#  'https://video-gameskz.ru',
#  'https://megynkelly.com',
#  'https://bkbet.group',
#  'https://24-cheki.xyz',
#  'https://babyblue.jp',
#  'https://poltekkes-kaltim.ac.id',
#  'https://fursaw.xyz',
#  'https://cdnkk.top',
#  'https://lemon.sa',
#  'https://selfanimate.com',
#  'https://thecrowdfundingformula.com',
#  'https://inatel.br',
#  'https://soyreferee.com',
#  'https://samsonite.com.tr',
#  'https://animehentaivideos2cn.com',
#  'https://unoprivateers.com',
#  'https://edi-art.net',
#  'https://rickytravelplus.com',
#  'https://ialman.it',
#  'https://basengreen.com',
#  'https://hempoilsuk.com',
#  'https://super5.org',
#  'https://thorlabs.de',
#  'https://inretecom.net',
#  'https://rainwave.cc',
#  'https://mcleodsoftware.com',
#  'https://chacruna.net',
#  'https://carlosgutierrez.com.uy',
#  'https://giant.com.my',
#  'https://zeuscasino.pro',
#  'https://umeng.co',
#  'https://toolara.net',
#  'https://posmotrim.com.ua',
#  'https://terrabrasilnoticias.com',
#  'https://partyrama.co.uk',
#  'https://saasexch.com',
#  'https://gvxrnq.com',
#  'https://polyfrost.cc',
#  'https://yuriscenes.com',
#  'https://emolecules.com',
#  'https://creditopopularemprestimos.com.br',
#  'https://ghoya.shop',
#  'https://166pay.cc',
#  'https://avamovie.shop',
#  'https://hostlinks.net',
#  'https://roua.ro',
#  'https://paramount-streaming.com',
#  'https://allkharkov.ua',
#  'https://envisionexperience.com',
#  'https://trstplse.com',
#  'https://acsite.net',
#  'https://derby.gov.uk',
#  'https://parcelcompare.com',
#  'https://globalcareerclub.com',
#  'https://rate.ee',
#  'https://neweracommunity.net',
#  'https://pleco.com',
#  'https://nakhonchaiair.com',
#  'https://reallifecam.com',
#  'https://adcritic.com',
#  'https://nimbitmusic.com',
#  'https://mtdisplays.com',
#  'https://cucinelube.it',
#  'https://samsungcsportal.com',
#  'https://edmondscooking.co.nz',
#  'https://badgerofhonor.com',
#  'https://adobeereg.com',
#  'https://assortion.com',
#  'https://discord.me',
#  'https://ckie.dev',
#  'https://unifyed.com',
#  'https://efletexia.com',
#  'https://shio-berastogel.com',
#  'https://capcutproo.com',
#  'https://fossibot.com',
#  'https://transunion.co',
#  'https://vp-dns.net',
#  'https://server-mail.com',
#  'https://roosters.com.au',
#  'https://thomasnet-navigator.com',
#  'https://redsharknews.com',
#  'https://indoera.in',
#  'https://kumaroyunlari.net',
#  'https://nac.no',
#  'https://tomcatbrand.com',
#  'https://diamondrehabthailand.com',
#  'https://die-bibel.de',
#  'https://hope-education.co.uk',
#  'https://thinktheology.co.uk',
#  'https://maiyisupply.com',
#  'https://ipoac.nl',
#  'https://podomoro138a.online',
#  'https://ejercito.mil.ar',
#  'https://novelskidunya.com',
#  'https://sys-uptime.com',
#  'https://ipc-oil.ru',
#  'https://penntanklines.com',
#  'https://crosswordsolver.com',
#  'https://openstreetbrowser.org',
#  'https://lottus.com',
#  'https://navakal.in',
#  'https://mogulbound.io',
#  'https://pandra.ma',
#  'https://cokucuzasite.com',
#  'https://wemesh.com',
#  'https://cricwaves.com',
#  'https://teamos.xyz',
#  'https://ayo788ih.com',
#  'https://atxinc.com',
#  'https://theengineeringmindset.com',
#  'https://megagames.com',
#  'https://belenkacdn.com',
#  'https://openbusiness.ru',
#  'https://welcometaito.com',
#  'https://chick.com',
#  'https://disclosureofficial.com',
#  'https://catit.com',
#  'https://gulfbusiness.com',
#  'https://getthelook.com.ar',
#  'https://er4uenterprise.in',
#  'https://larocheposay.com.au',
#  'https://nova1.net',
#  'https://pddugc.com',
#  'https://1zeh.kz',
#  'https://klto9.com',
#  'https://ulridpage.com',
#  'https://vpoint-cp.jp',
#  'https://panelinzicht.nl',
#  'https://casinoaction.com',
#  'https://moofoupebogrizy.com',
#  'https://olhonocarro.com.br',
#  'https://highsierra.com.au',
#  'https://dzdaic.com',
#  'https://mcw.edu',
#  'https://iek.ru',
#  'https://vullkan-royall.site',
#  'https://45ru.net.au',
#  'https://agendaoffroad.com.br',
#  'https://safelinkinternet.com',
#  'https://blue-protocol.com',
#  'https://hemaos.com',
#  'https://cantabriainmobiliaria.pe',
#  'https://globalmunchkins.com',
#  'https://eisyayinlari.com',
#  'https://ruhosting.nl',
#  'https://zmero.com',
#  'https://tjkj300.com',
#  'https://pioneerwireless.net',
#  'https://cargoflash.com',
#  'https://myshopblocks.com',
#  'https://teleflex.com',
#  'https://vavada.media',
#  'https://mouseflow.com',
#  'https://ten-2026.com',
#  'https://ledmyplace.com',
#  'https://holiday88x.club',
#  'https://evisa.gov.kh',
#  'https://jetbahissitesi.com',
#  'https://uva.co.uk',
#  'https://vcweb.com.ar',
#  'https://akashi.lg.jp',
#  'https://bellotube.com',
#  'https://magpush.net',
#  'https://matteboken.se',
#  'https://tuazar.com',
#  'https://poee.pl',
#  'https://literatureandlatte.com',
#  'https://beprogrammer.com.co',
#  'https://eurosvet.ru',
#  'https://clsphila.org',
#  'https://chupi.com',
#  'https://healthtoptip.com',
#  'https://ezil.me',
#  'https://sellerthemes.com',
#  'https://kinogo-la.biz',
#  'https://russki-seriaal.net',
#  'https://meteolive.gr',
#  'https://garantiteknoloji.com.tr',
#  'https://fortnite.com',
#  'https://pageplanet.com',
#  'https://velammacomics.vip',
#  'https://drberg.ru',
#  'https://vulkan-russia-mirror.fun',
#  'https://kvo7.io',
#  'https://connewitz-leipzig.de',
#  'https://csaware.com',
#  'https://escapezoom.ir',
#  'https://1wumb.top',
#  'https://pelita27.shop',
#  'https://sunrider.com',
#  'https://59g1.com',
#  'https://pamico-czech.cz',
#  'https://uzz.edu.cn',
#  'https://casino-sol.rocks',
#  'https://yankeecandle.co.uk',
#  'https://lanostratv.it',
#  'https://sandersparks.com',
#  'https://pafikabsolok.com',
#  'https://koro-shop.it',
#  'https://serv00.com',
#  'https://destoon.com',
#  'https://unipart24.ru',
#  'https://cambriabike.com',
#  'https://criosweb.ro',
#  'https://evenium.net',
#  'https://openledger.xyz',
#  'https://awsdns-14.co.uk',
#  'https://facenama.com',
#  'https://giraffi.net',
#  'https://philips.hu',
#  'https://awsdns-26.org',
#  'https://mansonconstruction.com',
#  'https://hotandgirls.site',
#  'https://f-cf.pics',
#  'https://masukwong.com',
#  'https://skyvia.com',
#  'https://yoloogames.com',
#  'https://jbkwebhosting.com',
#  'https://nfldraftdiamonds.com',
#  'https://storemstv.net',
#  'https://fischipedia.org',
#  'https://66lottery21.com',
#  'https://rabato.com',
#  'https://yarnews.net',
#  'https://thehealthyjournal.com',
#  'https://quickbutik.com',
#  'https://ticketsbookmarks.com',
#  'https://fundaciondiabetes.org',
#  'https://shooliniuniversity.com',
#  'https://cricplus.pro',
#  'https://forum2go.nl',
#  'https://taketheleadmovie.com',
#  'https://cerzan.net',
#  'https://boutique-sd-equipements.fr',
#  'https://amino10.xyz',
#  'https://my3cx.de',
#  'https://dvdtown.com',
#  'https://projet13.com',
#  'https://osaka-kousha.or.jp',
#  'https://truckingshow.com',
#  'https://unicredit.ru',
#  'https://flashcom.com',
#  'https://mejtoft.se',
#  'https://adklimages.com',
#  'https://astol.pro',
#  'https://thestar.co.za',
#  'https://bank24.ru',
#  'https://durhammuseum.org',
#  'https://kangarootime.com',
#  'https://esim-plans.com',
#  'https://aulogirefaure.com',
#  'https://royalcanin.co.nz',
#  'https://lunaproxy.io',
#  'https://kniga.de',
#  'https://electrolux.com.my',
#  'https://wtqhosting.com',
#  'https://blogfa.com',
#  'https://gti.net',
#  'https://wildgay.com',
#  'https://marcmarquez93.com',
#  'https://jxrsrc.com',
#  'https://ze.tt',
#  'https://services-consultants.com',
#  'https://lidl.sk',
#  'https://revolution-energetique.com',
#  'https://wotgarage.net',
#  'https://solvis.net.br',
#  'https://technoblade.com',
#  'https://finastra.com',
#  'https://valpak.com',
#  'https://gangangangangangangangangangangan.com',
#  'https://bakersgas.com',
#  'https://wamgame.jp',
#  'https://teramoto.co.jp',
#  'https://hrs-api.com',
#  'https://crypto-bank.space',
#  'https://errordiary.org',
#  'https://nude.hu',
#  'https://ciberserver.net',
#  'https://earningswhispers.com',
#  'https://blacktarg.com.br',
#  'https://allcollectorcars.com',
#  'https://setram.dz',
#  'https://vandykes.com',
#  'https://clayops.com',
#  'https://eyelid.co.uk',
#  'https://allenandunwin.com',
#  'https://itesmedia.tv',
#  'https://arch01.xyz',
#  'https://simplaza.org',
#  'https://mscr.io',
#  'https://wfsu.org',
#  'https://sycer.biz',
#  'https://medischcontact.nl',
#  'https://msp.gob.do',
#  'https://ntust.edu.tw',
#  'https://gcicom.net',
#  'https://globalshares.io',
#  'https://onevideostube.com',
#  'https://franklinepb.net',
#  'https://baggallini.com',
#  'https://onlinelebenslauf.com',
#  'https://amazon.nl',
#  'https://click4riches.com',
#  'https://ppuhperspektywa.pl',
#  'https://bmcs.one',
#  'https://yourfoundation.org',
#  'https://daeguluck.kr',
#  'https://epaygo.bg',
#  'https://thgflow.com',
#  'https://finam.eu',
#  'https://malayalamsubtitles.org',
#  'https://bristlecone.com',
#  'https://khsport.net',
#  'https://wildneighbours.com',
#  'https://nzmaths.co.nz',
#  'https://allthatsinteresting.com',
#  'https://grigsoft.com',
#  'https://tehranbeautyclinic.com',
#  'https://opm.gov',
#  'https://robot.car',
#  'https://eurogirlescort.it',
#  'https://boleco.it',
#  'https://viiz.com',
#  'https://siteground180.com',
#  'https://trendhim.de',
#  'https://1sweetbonanza.com',
#  'https://garminstore.cl',
#  'https://ufato.ru',
#  'https://dirksgroup.com',
#  'https://bukvateka.com',
#  'https://mindfood.com',
#  'https://nonovpn.top',
#  'https://hudsonpot.com',
#  'https://valparaisodegoias.go.gov.br',
#  'https://dayworkonyachts.com',
#  'https://jobrapid.ro',
#  'https://datatower.ai',
#  'https://collaborate.center',
#  'https://byteworx.net',
#  'https://theclm.org',
#  'https://claws-mail.org',
#  'https://tellculvers.com',
#  'https://brightvpn.com',
#  'https://kmew.co.jp',
#  'https://dashdiet.org',
#  'https://legzocasinoprof6.top',
#  'https://veripay.tech',
#  'https://bit-incorp.com',
#  'https://griser.ru',
#  'https://techlandgg.com',
#  'https://englishworksheetsland.com',
#  'https://kingbam.co.kr',
#  'https://7x7-journal.ru',
#  'https://coneect.com.br',
#  'https://edunet.it',
#  'https://elaele.com.br',
#  'https://otvorenesudy.sk',
#  'https://gftya.jp',
#  'https://truyenazz.com.vn',
#  'https://reld.com.ar',
#  'https://fuehrerscheinindeutschland.com',
#  'https://spd.tech',
#  'https://omnivox.ca',
#  'https://fsdeveloper.com',
#  'https://onolearn.co.il',
#  'https://tuning-in.cz',
#  'https://tigo.net.bo',
#  'https://videodrugproject.com',
#  'https://dallmayr.de',
#  'https://muziekgebouw.nl',
#  'https://debitsuccess.com',
#  'https://jetwin77cuy.info',
#  'https://mairuan.com',
#  'https://mb66a.vip',
#  'https://ph84.idv.tw',
#  'https://manomano.it',
#  'https://23exch.com',
#  'https://imeilande.com',
#  'https://etrade.net',
#  'https://beefy.com',
#  'https://teaching-certification.com',
#  'https://36ok56cname.com',
#  'https://dancingsantacard.com',
#  'https://dreft.com',
#  'https://agendasp.online',
#  'https://gotab.io',
#  'https://itocservices.net',
#  'https://1topmatch.org',
#  'https://gdscans.com',
#  'https://toptable.com',
#  'https://24vulkany11.xyz',
#  'https://andtrip.jp',
#  'https://ymcart.com',
#  'https://asppa-net.org',
#  'https://enviromap.co.uk',
#  'https://modeledo.pl',
#  'https://pirulitoloja.com.br',
#  'https://egoshoes.com',
#  'https://wyethnutrition.co.id',
#  'https://congresmtl.com',
#  'https://alphamed-medical.com',
#  'https://icaslotspin.com',
#  'https://jcbgame.com',
#  'https://mybirdie.io',
#  'https://actualidad.xyz',
#  'https://gluon.com',
#  'https://tiendacanon.com.mx',
#  'https://novocolor.com.gt',
#  'https://jtdwjcwq6f4wp4ce.com',
#  'https://francaiscasinos.org',
#  'https://harima.lg.jp',
#  'https://ccifi.net',
#  'https://oil-city.ir',
#  'https://aclutx.org',
#  'https://tifi.net',
#  'https://realjoy.com',
#  'https://canalcar.es',
#  'https://shadowcasino.info',
#  'https://ravnododna.com',
#  'https://mercedes-benz.hr',
#  'https://velocityautogroup.autos',
#  'https://minsocam.org',
#  'https://hantamo.com',
#  'https://apisolving.com',
#  'https://zakupki44fz.ru',
#  'https://lyceascorce.top',
#  'https://imhentai.to',
#  'https://dstweb.net',
#  'https://whymy.ru',
#  'https://moontontech.net',
#  'https://overclockersclub.com',
#  'https://eventive.org',
#  'https://abcnews.al',
#  'https://mojoksini.sbs',
#  'https://nikeoutletstoreonlineshopping.us',
#  'https://giessener-zeitung.de',
#  'https://mp3xd.tv',
#  'https://dataconsultants.com',
#  'https://dvc.edu',
#  'https://caroom.fr',
#  'https://my-prtg.com',
#  'https://bigtimecollectibles.com',
#  'https://camdenartcentre.org',
#  'https://atmodigital.com',
#  'https://dimensi69r.com',
#  'https://bramaby.com',
#  'https://airtcp.xyz',
#  'https://m-idc.biz',
#  'https://nuforc.org',
#  'https://eldos-gamble.xyz',
#  'https://dhd.de',
#  'https://yamap.com',
#  'https://darkworlds.mobi',
#  'https://shyamolitickets.com',
#  'https://fhcibumn.id',
#  'https://1337x.to',
#  'https://kangwon.ac.kr',
#  'https://antebim.com',
#  'https://winstonwinghongto.com',
#  'https://lorealparisusa.com',
#  'https://russocapri.com',
#  'https://meineip.ovh',
#  'https://chrono24.jp',
#  'https://yogabars.in',
#  'https://intercable.ru',
#  'https://losangelesmission.org',
#  'https://hauptstadtkoffer.de',
#  'https://spinwin365.online',
#  'https://driverzone.com',
#  'https://greencastonline.com',
#  'https://insuremo.com',
#  'https://loteriademedellin.com.co',
#  'https://visumo.io',
#  'https://burckhardtcompression.com',
#  'https://bimcommunity.com',
#  'https://bigamericanshop.com',
#  'https://komienergo.ru',
#  'https://lytogame.com',
#  'https://tzuchi.org',
#  'https://kbusa.co.kr',
#  'https://sibill.com',
#  'https://upra.ao',
#  'https://sharkclean.com',
#  'https://scbbusinessnet.com',
#  'https://bzst.de',
#  'https://shpwbsrw.biz',
#  'https://simorghdarou.com',
#  'https://adobeevents.com',
#  'https://cartaholics.com',
#  'https://extra-tipp-am-sonntag.de',
#  'https://iizuka.lg.jp',
#  'https://lumu.io',
#  'https://tahua.net',
#  'https://futbet.xyz',
#  'https://vulkan-million-casino.xyz',
#  'https://exploresetoyota.com',
#  'https://clicksfordsm.com',
#  'https://7qf33jfovb3gri.xyz',
#  'https://expertsge.com',
#  'https://best-doctor.com.tw',
#  'https://palmsbet.com',
#  'https://safesecurehost.com',
#  'https://casino-online.vip',
#  'https://leecooper.fr',
#  'https://lindas.com.br',
#  'https://toquefibra.com.br',
#  'https://toreta-stamp.com',
#  'https://freebit.com',
#  'https://ratedrnb.com',
#  'https://mns.com',
#  'https://nihe.gov.uk',
#  'https://about-drinks.com',
#  'https://duoplus.nl',
#  'https://santil.com.br',
#  'https://weareeverise.com',
#  'https://vlkst49.club',
#  'https://guodegang.org',
#  'https://sweepscrush.com',
#  'https://bajibd-offer.com',
#  'https://crediweb.lv',
#  'https://safe-redirect.net',
#  'https://matwprojectusa.org',
#  'https://fymasauctions.dk',
#  'https://windly.cc',
#  'https://businessworld.in',
#  'https://777azino777.ru',
#  'https://vnews.com',
#  'https://inlight.academy',
#  'https://sentinelsource.com',
#  'https://wac-dc-msedge.net',
#  'https://mansfieldoil.com',
#  'https://florabelle.com.au',
#  'https://breathingtravel.com',
#  'https://aimhigh.com',
#  'https://hl0803.com',
#  'https://youarethemodel.com',
#  'https://impedimentdense.com',
#  'https://vredespaleis.nl',
#  'https://efisiensi.id',
#  'https://earn843.xyz',
#  'https://playnexusfn.com',
#  'https://librarius.com',
#  'https://livelyuniversity.com',
#  'https://foxfordschool.com',
#  'https://protechtgroup.com',
#  'https://lms-app.in',
#  'https://homedeptcomsurvey.us',
#  'https://nextos.com',
#  'https://lmcau.vip',
#  'https://xx.pl',
#  'https://anyan.com',
#  'https://mgmslotslive.com',
#  'https://transactall.com',
#  'https://manchtech.in',
#  'https://public-i.tv',
#  'https://tgnns.com',
#  'https://bibvip12.app',
#  'https://buyon.ru',
#  'https://revhq.com',
#  'https://justkampers.com',
#  'https://france-xenon.com',
#  'https://sd-assets.com',
#  'https://horsequest.co.uk',
#  'https://hentai-id.tv',
#  'https://hidden247.com',
#  'https://mitradel.gob.pa',
#  'https://wormly.com',
#  'https://mo-net.com',
#  'https://blueman.com',
#  'https://1a2c.com',
#  'https://mostbet-az-giris.com',
#  'https://kentuckyfriedcruelty.com',
#  'https://ahoracalafate.com.ar',
#  'https://intaserve.net',
#  'https://4rabet-india.in',
#  'https://bigmartup.com',
#  'https://sexkche.me',
#  'https://jesenice.net',
#  'https://rrllc.ru',
#  'https://tbmm.gov.tr',
#  'https://supersalon.com',
#  'https://padelmagazine.fr',
#  'https://turkcinema.org',
#  'https://amp-endpoint2.com',
#  'https://adxrect.info',
#  'https://readthedocs.io',
#  'https://htlimpiankita.site',
#  'https://goldentea.ltd',
#  'https://infosupport.com',
#  'https://intuit.com',
#  'https://skriware.com',
#  'https://bicoop.shop',
#  'https://hosbeg.com',
#  'https://wfiwradio.com',
#  'https://microventures.com',
#  'https://arkada-casino-official.buzz',
#  'https://upobpas.in',
#  'https://uy11kkan.com',
#  'https://musics-box.ir',
#  'https://happysteelindustry.com',
#  'https://cloudrack360.com',
#  'https://r7-kazino-zerkalo.ru',
#  'https://grandpashabet.biz',
#  'https://opera-mini.net',
#  'https://efgraphics.com',
#  'https://dynamicnetworkservices.net',
#  'https://latestlaws.com',
#  'https://postar.cn',
#  'https://allsparks.com',
#  'https://easyonlinehomejobs.com',
#  'https://astralinternet.com',
#  'https://kizzitr.com',
#  'https://lxcdns.com',
#  'https://anthempress.com',
#  'https://arthur.io',
#  'https://grand-lisboaonline.com',
#  'https://trayvonious.com',
#  'https://albertacom.com',
#  'https://wga.com',
#  'https://gclub168.com',
#  'https://pafnow.com',
#  'https://telesoldiario.com',
#  'https://truelink.net',
#  'https://onche.org',
#  'https://prismhr.com',
#  'https://grupoavisolucoes.com.br',
#  'https://headlime.com',
#  'https://obmorju.si',
#  'https://tangerine.ca',
#  'https://sony.com.cn',
#  'https://asianodds.com',
#  'https://kentalis.nl',
#  'https://gigacloud.ua',
#  'https://baza-knig.fun',
#  'https://1xbet.bj',
#  'https://inforitus.nl',
#  'https://sparkasse-mainfranken.de',
#  'https://ich-5.com',
#  'https://b9game7.com',
#  'https://ashford-style.com',
#  'https://sayclub.com',
#  'https://constructiv.be',
#  'https://csmarket.gg',
#  'https://vulkan24-site.com',
#  'https://pessoacomdeficiencia.sp.gov.br',
#  'https://covatic.io',
#  'https://doppiocdn.com',
#  'https://cyrusone.com',
#  'https://virtualsoft.tech',
#  'https://thethaiger.com',
#  'https://artivet.com',
#  'https://sound.jp',
#  'https://runnigcllecd.com',
#  'https://yournucleus.ca',
#  'https://maria33312.com',
#  'https://lawwwing.com',
#  'https://agro-market.net',
#  'https://gomibo.ie',
#  'https://ppcenergy.ro',
#  'https://iloveveterinary.com',
#  'https://schuttrange.lu',
#  'https://verybigblog.com',
#  'https://sportline.cr',
#  'https://vaultre.com.au',
#  ...]

# %%
# Label data
urls = phishing_urls + benign_urls
labels = [1]*len(phishing_urls) + [0]*len(benign_urls)
# Feature extraction
def extract_features(url):
    parsed = urlparse(url)
    hostname = parsed.hostname or ''
    full_url = url.lower()
    specials = ['%', '-', '=', '&', ';']
    keywords = ['login', 'verify', 'secure', 'account', 'signin']

    def entropy(domain):
        counts = {char: domain.count(char) for char in set(domain)}
        length = len(domain)
        return -sum((f / length) * math.log2(f / length) for f in counts.values())
    
    raw_entropy = entropy(hostname)
    entropy_binary = 1 if raw_entropy > 3.9 else 0  # Binary conversion

    return {
        'url_length': len(full_url),
        'dot_count': hostname.count('.'),
        'has_at': '@' in full_url,
        'special_char_count': sum(full_url.count(ch) for ch in specials),
        'entropy': raw_entropy,
        'suspicious_keywords': sum(kw in full_url for kw in keywords),
        'subdomain_length': sum(len(part) for part in hostname.split('.')[:-2]) if hostname.count('.') >= 2 else 0,
        'is_ip': bool(re.match(r'^\d{1,3}(\.\d{1,3}){3}$', hostname))
    }

# Build dataframe
features = [extract_features(url) for url in urls]
df = pd.DataFrame(features)
df['label'] = labels

X = df.drop("label", axis=1)
y = df["label"]

# Normalize features - use RobustScaler to handle outliers
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# RFE for feature selection - Recursive Feature Elimination
print("\nPerforming Recursive Feature Elimination (RFE)...")
model = LogisticRegression()
rfe = RFE(model, n_features_to_select=5)
fit = rfe.fit(X_scaled, y)
print("RFE-selected:", X.columns[fit.support_])

# choose the best features
X_selected = X_scaled[:, fit.support_]

# Cross-validation with multiple k values
print("\nEvaluating model with k-fold cross-validation:")
k_options = [3, 5, 7, 10, 15]
best_k = None
best_score = 0

for k in k_options:
    skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
    model = LogisticRegression()
    scores = cross_val_score(model, X_selected, y, cv=skf, scoring='accuracy')
    mean_score = scores.mean()
    print(f"k={k} | Mean Accuracy: {mean_score:.4f}")
    if mean_score > best_score:
        best_score = mean_score
        best_k = k

print(f"\nBest k found: {best_k} with accuracy: {best_score:.4f}")


# Final training on the selected features
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

final_model = LogisticRegression()
final_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)

# Classification report
y_probs = final_model.predict_proba(X_test)[:, 1]  # סיכוי לפישינג


# Export model weights
print("\nJavaScript-ready weights:")
print("const weights = {")
for name, coef in zip(X.columns, final_model.coef_[0]):
    print(f"  {name}: {coef:.4f},")
print("};")
print(f"const bias = {final_model.intercept_[0]:.4f};")

# Evaluate model performance
print("\nEvaluating model performance...")
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
tpr = tp / (tp + fn)
fpr = fp / (fp + tn)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"True Positive Rate (TPR / Recall): {tpr:.4f}")
print(f"False Positive Rate (FPR): {fpr:.4f}")
# Out:
# Performing Recursive Feature Elimination (RFE)...
# RFE-selected: Index(['url_length', 'dot_count', 'has_at', 'entropy', 'is_ip'], dtype='object')
#
# Evaluating model with k-fold cross-validation:
# k=3 | Mean Accuracy: 0.8819
# k=5 | Mean Accuracy: 0.8812
# k=7 | Mean Accuracy: 0.8809
# k=10 | Mean Accuracy: 0.8808

# %% [markdown]
# Mark Data

# %%
df.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='label', y='entropy', hue='label')
plt.title('Entropy by Label')
plt.xlabel('Label (0 = Benign, 1 = Phishing)')
plt.ylabel('Entropy')
plt.show()

# %%
print(len(df[(df['label'] == 1) & (df['entropy'] > threshold)]), len(df[(df['label'] == 0) & (df['entropy'] > threshold)]))

# %%
len(df[(df['label'] == 1) & (df['entropy'] > threshold)])/len(df[(df['label'] == 0) & (df['entropy'] > threshold)])

# %%
df['id'] = df.index
df = df[df['url_length'] < 20]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='id', y='url_length', hue='label',s=10)
plt.title('length by Label')
plt.xlabel('Label (0 = Benign, 1 = Phishing)')
plt.ylabel('url length')
plt.show()

# %%
# Calculate precision (how much out of the phishing sites are detected)
# for thresholds from 0.0 to 1.0
thresholds = np.linspace(0, 1, 100)
precisions = []
recalls = []
f1_scores = []

# Calculate precision, recall, and F1 score for each threshold
for t in thresholds:
    y_pred_thresh = (y_probs >= t).astype(int)
    precisions.append(precision_score(y_test, y_pred_thresh, zero_division=0))
    recalls.append(recall_score(y_test, y_pred_thresh))
    f1_scores.append(f1_score(y_test, y_pred_thresh))

# Plot all three metrics
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precisions, label='Precision', color='blue')
plt.plot(thresholds, recalls, label='Recall', color='green')
plt.plot(thresholds, f1_scores, label='F1 Score', color='purple')
plt.xlabel('Classification Threshold')
plt.ylabel('Score')
plt.title('Precision, Recall & F1 Score vs Threshold')
plt.legend()
plt.grid(True)
plt.show()

# %%
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_idx, best_threshold

# %%
df['has_at'].sum()  # כמה דגימות יש עם '@'

# %% [markdown]
# ### K-Means Clustering Result

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=df_features['cluster'], palette='viridis')
plt.title('K-Means Clustering (2D Projection)')
plt.xlabel('Feature 1 (scaled)')
plt.ylabel('Feature 2 (scaled)')
plt.show()

# %% [markdown]
# ### Logistic Regression Weights & Bias

# %%
import pandas as pd
feature_names = X.columns
weights = pd.Series(model.coef_[0], index=feature_names)
weights.plot(kind='barh', figsize=(8,6), title='Feature Weights')
plt.axvline(0, color='red', linestyle='--')
plt.show()
print(f'Bias: {model.intercept_[0]:.4f}')

# %% [markdown]
# ### Cross-Validation Accuracy

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
k_values = [3, 5, 7, 10]
for k in k_values:
    skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
    scores = cross_val_score(LogisticRegression(), X_scaled, y, cv=skf, scoring='accuracy')
    print(f'k={k}: Accuracy = {scores.mean():.4f}')
